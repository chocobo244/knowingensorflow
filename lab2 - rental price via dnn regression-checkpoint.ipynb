# %% [markdown]
# # Lab - Rental Price
# Reference: Dataset was extracted from one of the popular property listing site (updated to Sep 2018)
#
# Exercise:
# 1. Try train on all states dataset, then predict the rental based on selected features
# 2. Try train on only Selangor dataset, then predict the rental based on selected features

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil

# %% [markdown]
# ## Read dataset

# %%
df_orig = pd.read_csv("./data/proprental/RentIndexRaw.csv", low_memory=False)
COLUMNS = list(df_orig)
print (COLUMNS)
# Out:
# ['ID', 'BuiltUpSize', 'City', 'CreatedDateTime', 'CreatedUser', 'DataSourceID', 'Furnishing', 'Latitude', 'Longitude', 'NoOfBathroom', 'NoOfBedroom', 'NoOfParking', 'Postcode', 'PostedDate', 'PropertyAddress', 'PropertyName', 'PropertyType', 'RentalPerMth', 'SourceUrl', 'State', 'UpdatedDateTime', 'UpdatedUser']

# %% [markdown]
# ## Preparing dataset metadata

# %%
print('Original dataset: {}'.format(df_orig.shape))

df_orig['State'] = df_orig['State'].str.upper()
df_orig['City'] = df_orig['City'].str.upper()
df_orig['PropertyType'] = df_orig['PropertyType'].str.upper()

# Selangor
df_sel = df_orig[(df_orig.State == 'SELANGOR')]
print('Selangor dataset: {}'.format(df_sel.shape))

# KL
df_kul = df_orig[(df_orig.State == 'KUALA-LUMPUR')]
print('KL dataset: {}'.format(df_kul.shape))


# remove rows with zero value
df = df_sel[(df_sel[['BuiltUpSize','RentalPerMth', 'NoOfBedroom']] != 0).all(axis=1)]
                            #'NoOfBathroom', 'NoOfParking']] != 0).all(axis=1)]


print('Wanted dataset: {}'.format(df.shape))
# Out:
# Original dataset: (54405, 22)
# Selangor dataset: (30292, 22)
# KL dataset: (13648, 22)
# Wanted dataset: (20626, 22)

# %% [markdown]
# ## Split into dataset of: Train, Validation, Test (70%-20%-10%)

# %%
df_train0, df_valid0, df_test0 = np.split(df.sample(frac=1), [int(.7*len(df)), int(.9*len(df))])

# Retrieve only Featured columns
df_train = df_train0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]
df_valid = df_valid0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]
df_test = df_test0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]

print('Train: {}'.format(df_train.shape))
print('Valid: {}'.format(df_valid.shape))
print('Test: {}'.format(df_test.shape))
# Out:
# Train: (14438, 6)
# Valid: (4125, 6)
# Test: (2063, 6)

# %% [markdown]
# ## Categorize string value columns

# %%
df_train['PropertyType'].unique()
# Out:
# array(['CONDOMINIUM', 'SERVICED RESIDENCE', 'SEMI-DETACHED HOUSE',
#        '2-STY TERRACE/LINK HOUSE', 'APARTMENT',
#        '2.5-STY TERRACE/LINK HOUSE', 'TOWNHOUSE',
#        '3-STY TERRACE/LINK HOUSE', 'FLAT', '3.5-STY TERRACE/LINK HOUSE',
#        '1-STY TERRACE/LINK HOUSE', 'BUNGALOW', 'CLUSTER HOUSE',
#        '1.5-STY TERRACE/LINK HOUSE', '4-STY TERRACE/LINK HOUSE'],
#       dtype=object)

# %%
df_train['State'].unique()
# Out:
# array(['SELANGOR'], dtype=object)

# %% [markdown]
# ## Determine metrics for validation - RMSE

# %%
def print_rmse(model, df):
  metrics = model.evaluate(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    shuffle = False,
    #queue_capacity = 100
      
  ))
  print('RMSE on dataset = {}'.format(np.sqrt(metrics['average_loss'])))
    
#print_rmse(model, df_valid)

# %% [markdown]
# ## Model: DNNRegressor

# %%
# DNNRegressor

LABEL = 'RentalPerMth'
OUTDIR = 'model/lab2_regress_rental'
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

# Categorize string features
categorical_column1 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="State", vocabulary_list=['SELANGOR', 'JOHOR', 'KUALA-LUMPUR', 'PUTRAJAYA'], 
    default_value=0)

categorical_column2 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="Furnishing", vocabulary_list=['Unfurnished', 'Fully Furnished', 'Partly Furnished', 'Unknown'], 
    default_value=0)

categorical_column3 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="PropertyType", vocabulary_list=['CONDOMINIUM', 'SERVICED RESIDENCE', 'APARTMENT',
       '2-STY TERRACE/LINK HOUSE', '3-STY TERRACE/LINK HOUSE',
       '1-STY TERRACE/LINK HOUSE', 'TOWNHOUSE', 'SEMI-DETACHED HOUSE',
       'BUNGALOW', '1.5-STY TERRACE/LINK HOUSE',
       '3.5-STY TERRACE/LINK HOUSE', 'CLUSTER HOUSE', 'FLAT',
       '2.5-STY TERRACE/LINK HOUSE', '4-STY TERRACE/LINK HOUSE',
       'RESIDENTIAL LAND'], 
    default_value=0)


model = tf.estimator.DNNRegressor(    
    hidden_units = [64, 2048, 64],
    feature_columns = [tf.feature_column.numeric_column('BuiltUpSize'),
                       tf.feature_column.numeric_column('NoOfBedroom'),
                       #tf.feature_column.indicator_column(categorical_column1),
                       tf.feature_column.indicator_column(categorical_column2),
                       tf.feature_column.indicator_column(categorical_column3)
                      ], 
    activation_fn = tf.nn.relu,
    optimizer=tf.train.AdamOptimizer(
        learning_rate=0.001,
        #l1_regularization_strength=0.01
    ),

    model_dir = OUTDIR
)
 

model.train(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df_train,
    y = df_train[LABEL],
    batch_size = 128,
    num_epochs = 5,
    shuffle = True,
  )
  );

print_rmse(model, df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'model/lab2_regress_rental', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x126170c88>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/thenghui/Documents/My Trainer/workspace/thlab/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/thenghui/Documents/My Trainer/workspace/thlab/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/thenghui/Documents/My Trainer/workspace/thlab/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/thenghui/Documents/My Trainer/workspace/thlab/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into model/lab2_regress_rental/model.ckpt.
# INFO:tensorflow:loss = 542535230.0, step = 1
# INFO:tensorflow:global_step/sec: 104.208
# INFO:tensorflow:loss = 104629170.0, step = 101 (0.961 sec)
# INFO:tensorflow:global_step/sec: 95.8061
# INFO:tensorflow:loss = 86882580.0, step = 201 (1.044 sec)
# INFO:tensorflow:global_step/sec: 118.124
# INFO:tensorflow:loss = 101858500.0, step = 301 (0.847 sec)
# INFO:tensorflow:global_step/sec: 126.274
# INFO:tensorflow:loss = 234866430.0, step = 401 (0.792 sec)
# INFO:tensorflow:global_step/sec: 124.993
# INFO:tensorflow:loss = 152457860.0, step = 501 (0.800 sec)
# INFO:tensorflow:Saving checkpoints for 564 into model/lab2_regress_rental/model.ckpt.
# INFO:tensorflow:Loss for final step: 135187870.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-14:33:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model/lab2_regress_rental/model.ckpt-564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-14:33:46
# INFO:tensorflow:Saving dict for global step 564: average_loss = 328004260.0, global_step = 564, label/mean = 2563.5203, loss = 41000534000.0, prediction/mean = 2116.543
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 564: model/lab2_regress_rental/model.ckpt-564
# RMSE on dataset = 18110.888671875

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(input_fn = tf.estimator.inputs.pandas_input_fn(
#    x = pd.DataFrame({
#                      'BuiltUpSize':[560,1200,1600],
#                      'NoOfBedroom':[2,3,3],
#                      'PropertyType':['CONDOMINIUM', 'SERVICED RESIDENCE', 'APARTMENT'],
#                      'Furnishing':['Unfurnished', 'Fully Furnished', 'Partly Furnished']}),
    x = df_test,
    y = None,
    batch_size = 128,
    shuffle = False
  ))

for items in predictions:
  print(items)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model/lab2_regress_rental/model.ckpt-564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([3386.6013], dtype=float32)}
# {'predictions': array([1318.4175], dtype=float32)}
# {'predictions': array([1855.0232], dtype=float32)}
# {'predictions': array([1353.8215], dtype=float32)}
# {'predictions': array([1216.7614], dtype=float32)}
# {'predictions': array([1957.7964], dtype=float32)}
# {'predictions': array([1649.9349], dtype=float32)}
# {'predictions': array([1712.261], dtype=float32)}
# {'predictions': array([1856.8087], dtype=float32)}
# {'predictions': array([1327.0762], dtype=float32)}
# {'predictions': array([851.8212], dtype=float32)}
# {'predictions': array([4490.1646], dtype=float32)}
# {'predictions': array([2472.92], dtype=float32)}
# {'predictions': array([1996.8523], dtype=float32)}
# {'predictions': array([1850.2166], dtype=float32)}
# {'predictions': array([1484.7263], dtype=float32)}
# {'predictions': array([1130.0316], dtype=float32)}
# {'predictions': array([1080.4552], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([1158.9009], dtype=float32)}
# {'predictions': array([1999.6495], dtype=float32)}
# {'predictions': array([1503.3096], dtype=float32)}
# {'predictions': array([1937.2661], dtype=float32)}
# {'predictions': array([991.91864], dtype=float32)}
# {'predictions': array([1587.0557], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([1817.6145], dtype=float32)}
# {'predictions': array([1749.4315], dtype=float32)}
# {'predictions': array([1978.9973], dtype=float32)}
# {'predictions': array([2534.389], dtype=float32)}
# {'predictions': array([2847.0715], dtype=float32)}
# {'predictions': array([1827.0273], dtype=float32)}
# {'predictions': array([2288.818], dtype=float32)}
# {'predictions': array([1907.282], dtype=float32)}
# {'predictions': array([945.1404], dtype=float32)}
# {'predictions': array([1591.003], dtype=float32)}
# {'predictions': array([2160.0374], dtype=float32)}
# {'predictions': array([1683.3564], dtype=float32)}
# {'predictions': array([1406.0779], dtype=float32)}
# {'predictions': array([1935.2778], dtype=float32)}
# {'predictions': array([1906.3302], dtype=float32)}
# {'predictions': array([1913.6737], dtype=float32)}
# {'predictions': array([1090.8374], dtype=float32)}
# {'predictions': array([2326.2678], dtype=float32)}
# {'predictions': array([1357.8119], dtype=float32)}
# {'predictions': array([1051.6432], dtype=float32)}
# {'predictions': array([2424.3127], dtype=float32)}
# {'predictions': array([1689.6497], dtype=float32)}
# {'predictions': array([1794.2249], dtype=float32)}
# {'predictions': array([6722.6167], dtype=float32)}
# {'predictions': array([1890.5256], dtype=float32)}
# {'predictions': array([2482.9226], dtype=float32)}
# {'predictions': array([1522.9252], dtype=float32)}
# {'predictions': array([1591.2034], dtype=float32)}
# {'predictions': array([2000.6014], dtype=float32)}
# {'predictions': array([1270.0918], dtype=float32)}
# {'predictions': array([1688.163], dtype=float32)}
# {'predictions': array([1558.4818], dtype=float32)}
# {'predictions': array([1972.5247], dtype=float32)}
# {'predictions': array([2059.4524], dtype=float32)}
# {'predictions': array([2157.3782], dtype=float32)}
# {'predictions': array([2440.1985], dtype=float32)}
# {'predictions': array([1401.5315], dtype=float32)}
# {'predictions': array([1594.6406], dtype=float32)}
# {'predictions': array([1590.0392], dtype=float32)}
# {'predictions': array([1966.174], dtype=float32)}
# {'predictions': array([2581.841], dtype=float32)}
# {'predictions': array([1765.5583], dtype=float32)}
# {'predictions': array([1651.4485], dtype=float32)}
# {'predictions': array([1775.8832], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([922.7404], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([2240.292], dtype=float32)}
# {'predictions': array([2022.0464], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([1500.409], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([2433.6038], dtype=float32)}
# {'predictions': array([2255.3452], dtype=float32)}
# {'predictions': array([1945.5243], dtype=float32)}
# {'predictions': array([2249.6238], dtype=float32)}
# {'predictions': array([2175.9614], dtype=float32)}
# {'predictions': array([1242.0149], dtype=float32)}
# {'predictions': array([1711.5258], dtype=float32)}
# {'predictions': array([1598.5762], dtype=float32)}
# {'predictions': array([1408.2046], dtype=float32)}
# {'predictions': array([2246.965], dtype=float32)}
# {'predictions': array([1316.6704], dtype=float32)}
# {'predictions': array([1442.592], dtype=float32)}
# {'predictions': array([1717.9058], dtype=float32)}
# {'predictions': array([3734.5464], dtype=float32)}
# {'predictions': array([1774.983], dtype=float32)}
# {'predictions': array([1600.4425], dtype=float32)}
# {'predictions': array([4487.3667], dtype=float32)}
# {'predictions': array([876.14514], dtype=float32)}
# {'predictions': array([1314.0115], dtype=float32)}
# {'predictions': array([1823.2944], dtype=float32)}
# {'predictions': array([2900.001], dtype=float32)}
# {'predictions': array([1328.9426], dtype=float32)}
# {'predictions': array([1690.822], dtype=float32)}
# {'predictions': array([2056.593], dtype=float32)}
# {'predictions': array([1903.6711], dtype=float32)}
# {'predictions': array([2334.485], dtype=float32)}
# {'predictions': array([1655.3606], dtype=float32)}
# {'predictions': array([4301.7397], dtype=float32)}
# {'predictions': array([2188.0977], dtype=float32)}
# {'predictions': array([1999.6495], dtype=float32)}
# {'predictions': array([1791.5659], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([1738.2332], dtype=float32)}
# {'predictions': array([1082.3789], dtype=float32)}
# {'predictions': array([1137.4971], dtype=float32)}
# {'predictions': array([1740.4219], dtype=float32)}
# {'predictions': array([2227.2273], dtype=float32)}
# {'predictions': array([2342.9434], dtype=float32)}
# {'predictions': array([1702.0203], dtype=float32)}
# {'predictions': array([1799.2462], dtype=float32)}
# {'predictions': array([2848.735], dtype=float32)}
# {'predictions': array([3770.008], dtype=float32)}
# {'predictions': array([1557.1359], dtype=float32)}
# {'predictions': array([1615.0515], dtype=float32)}
# {'predictions': array([2987.991], dtype=float32)}
# {'predictions': array([2848.735], dtype=float32)}
# {'predictions': array([2179.9895], dtype=float32)}
# {'predictions': array([10775.304], dtype=float32)}
# {'predictions': array([1791.5659], dtype=float32)}
# {'predictions': array([4253.403], dtype=float32)}
# {'predictions': array([1032.0647], dtype=float32)}
# {'predictions': array([2184.243], dtype=float32)}
# {'predictions': array([2945.99], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([1128.1652], dtype=float32)}
# {'predictions': array([2078.99], dtype=float32)}
# {'predictions': array([1936.8865], dtype=float32)}
# {'predictions': array([2342.9434], dtype=float32)}
# {'predictions': array([1740.4219], dtype=float32)}
# {'predictions': array([1935.4926], dtype=float32)}
# {'predictions': array([1486.512], dtype=float32)}
# {'predictions': array([1718.6958], dtype=float32)}
# {'predictions': array([5230.3794], dtype=float32)}
# {'predictions': array([1649.9349], dtype=float32)}
# {'predictions': array([1464.1962], dtype=float32)}
# {'predictions': array([1791.5659], dtype=float32)}
# {'predictions': array([2012.7144], dtype=float32)}
# {'predictions': array([1447.4913], dtype=float32)}
# {'predictions': array([1055.376], dtype=float32)}
# {'predictions': array([1594.8434], dtype=float32)}
# {'predictions': array([4253.403], dtype=float32)}
# {'predictions': array([2190.0215], dtype=float32)}
# {'predictions': array([2134.9814], dtype=float32)}
# {'predictions': array([1613.1277], dtype=float32)}
# {'predictions': array([1982.7302], dtype=float32)}
# {'predictions': array([1221.3053], dtype=float32)}
# {'predictions': array([2570.6428], dtype=float32)}
# {'predictions': array([1130.0316], dtype=float32)}
# {'predictions': array([1754.4526], dtype=float32)}
# {'predictions': array([2799.605], dtype=float32)}
# {'predictions': array([3561.5764], dtype=float32)}
# {'predictions': array([2433.6038], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([1749.7537], dtype=float32)}
# {'predictions': array([1593.7288], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([2059.3743], dtype=float32)}
# {'predictions': array([1500.6504], dtype=float32)}
# {'predictions': array([850.07306], dtype=float32)}
# {'predictions': array([1917.5286], dtype=float32)}
# {'predictions': array([2442.8577], dtype=float32)}
# {'predictions': array([1757.0543], dtype=float32)}
# {'predictions': array([1827.7625], dtype=float32)}
# {'predictions': array([3770.008], dtype=float32)}
# {'predictions': array([2267.6172], dtype=float32)}
# {'predictions': array([1131.898], dtype=float32)}
# {'predictions': array([2693.8247], dtype=float32)}
# {'predictions': array([1592.0767], dtype=float32)}
# {'predictions': array([2246.965], dtype=float32)}
# {'predictions': array([2329.8787], dtype=float32)}
# {'predictions': array([4108.6978], dtype=float32)}
# {'predictions': array([1687.0481], dtype=float32)}
# {'predictions': array([1662.7849], dtype=float32)}
# {'predictions': array([2341.199], dtype=float32)}
# {'predictions': array([2026.7722], dtype=float32)}
# {'predictions': array([1220.6921], dtype=float32)}
# {'predictions': array([1200.8325], dtype=float32)}
# {'predictions': array([3089.4993], dtype=float32)}
# {'predictions': array([1417.3337], dtype=float32)}
# {'predictions': array([1691.6954], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([1131.898], dtype=float32)}
# {'predictions': array([2406.5227], dtype=float32)}
# {'predictions': array([1689.6497], dtype=float32)}
# {'predictions': array([1130.0316], dtype=float32)}
# {'predictions': array([1868.019], dtype=float32)}
# {'predictions': array([1145.7144], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([2718.2097], dtype=float32)}
# {'predictions': array([5857.9688], dtype=float32)}
# {'predictions': array([1803.6787], dtype=float32)}
# {'predictions': array([1130.0316], dtype=float32)}
# {'predictions': array([1503.1901], dtype=float32)}
# {'predictions': array([3738.0046], dtype=float32)}
# {'predictions': array([941.40424], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1464.1962], dtype=float32)}
# {'predictions': array([1148.6954], dtype=float32)}
# {'predictions': array([1778.6206], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1689.707], dtype=float32)}
# {'predictions': array([2811.4883], dtype=float32)}
# {'predictions': array([2056.634], dtype=float32)}
# {'predictions': array([1407.2091], dtype=float32)}
# {'predictions': array([1223.2292], dtype=float32)}
# {'predictions': array([1520.023], dtype=float32)}
# {'predictions': array([2372.9277], dtype=float32)}
# {'predictions': array([2250.4346], dtype=float32)}
# {'predictions': array([1827.7625], dtype=float32)}
# {'predictions': array([3137.3025], dtype=float32)}
# {'predictions': array([3641.2273], dtype=float32)}
# {'predictions': array([1957.7964], dtype=float32)}
# {'predictions': array([1684.3226], dtype=float32)}
# {'predictions': array([1135.6306], dtype=float32)}
# {'predictions': array([1856.8087], dtype=float32)}
# {'predictions': array([2433.6038], dtype=float32)}
# {'predictions': array([2407.5962], dtype=float32)}
# {'predictions': array([2948.6492], dtype=float32)}
# {'predictions': array([1826.9464], dtype=float32)}
# {'predictions': array([1666.559], dtype=float32)}
# {'predictions': array([2109.6448], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([2066.6604], dtype=float32)}
# {'predictions': array([1629.4048], dtype=float32)}
# {'predictions': array([1655.3606], dtype=float32)}
# {'predictions': array([1154.1729], dtype=float32)}
# {'predictions': array([1345.3605], dtype=float32)}
# {'predictions': array([1251.1675], dtype=float32)}
# {'predictions': array([1826.9464], dtype=float32)}
# {'predictions': array([1606.0417], dtype=float32)}
# {'predictions': array([1972.6467], dtype=float32)}
# {'predictions': array([2881.3372], dtype=float32)}
# {'predictions': array([1950.209], dtype=float32)}
# {'predictions': array([3362.0042], dtype=float32)}
# {'predictions': array([12513.172], dtype=float32)}
# {'predictions': array([1953.9417], dtype=float32)}
# {'predictions': array([2620.243], dtype=float32)}
# {'predictions': array([1297.8872], dtype=float32)}
# {'predictions': array([1148.6954], dtype=float32)}
# {'predictions': array([1605.6621], dtype=float32)}
# {'predictions': array([1754.9734], dtype=float32)}
# {'predictions': array([3734.5464], dtype=float32)}
# {'predictions': array([1682.3987], dtype=float32)}
# {'predictions': array([1735.5742], dtype=float32)}
# {'predictions': array([1665.444], dtype=float32)}
# {'predictions': array([2322.413], dtype=float32)}
# {'predictions': array([3740.95], dtype=float32)}
# {'predictions': array([2615.4482], dtype=float32)}
# {'predictions': array([1126.1194], dtype=float32)}
# {'predictions': array([4858.407], dtype=float32)}
# {'predictions': array([1858.7969], dtype=float32)}
# {'predictions': array([5045.046], dtype=float32)}
# {'predictions': array([1236.294], dtype=float32)}
# {'predictions': array([1809.0986], dtype=float32)}
# {'predictions': array([8410.647], dtype=float32)}
# {'predictions': array([2649.0315], dtype=float32)}
# {'predictions': array([2822.6057], dtype=float32)}
# {'predictions': array([1448.2266], dtype=float32)}
# {'predictions': array([5988.0825], dtype=float32)}
# {'predictions': array([1767.0453], dtype=float32)}
# {'predictions': array([1815.6907], dtype=float32)}
# {'predictions': array([1780.3674], dtype=float32)}
# {'predictions': array([1697.3298], dtype=float32)}
# {'predictions': array([814.61163], dtype=float32)}
# {'predictions': array([1839.0182], dtype=float32)}
# {'predictions': array([1260.6787], dtype=float32)}
# {'predictions': array([1140.4373], dtype=float32)}
# {'predictions': array([878.0689], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([1048.7839], dtype=float32)}
# {'predictions': array([2265.6292], dtype=float32)}
# {'predictions': array([1840.133], dtype=float32)}
# {'predictions': array([1940.0037], dtype=float32)}
# {'predictions': array([943.3926], dtype=float32)}
# {'predictions': array([1495.0247], dtype=float32)}
# {'predictions': array([941.40424], dtype=float32)}
# {'predictions': array([1917.5286], dtype=float32)}
# {'predictions': array([2262.8108], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([2182.556], dtype=float32)}
# {'predictions': array([1771.9856], dtype=float32)}
# {'predictions': array([1286.6863], dtype=float32)}
# {'predictions': array([2061.0613], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([866.8132], dtype=float32)}
# {'predictions': array([4107.824], dtype=float32)}
# {'predictions': array([1781.1028], dtype=float32)}
# {'predictions': array([1231.7684], dtype=float32)}
# {'predictions': array([1819.6836], dtype=float32)}
# {'predictions': array([2326.2268], dtype=float32)}
# {'predictions': array([1872.8136], dtype=float32)}
# {'predictions': array([2416.9282], dtype=float32)}
# {'predictions': array([2064.9731], dtype=float32)}
# {'predictions': array([2305.6157], dtype=float32)}
# {'predictions': array([1504.183], dtype=float32)}
# {'predictions': array([1354.8718], dtype=float32)}
# {'predictions': array([1413.6008], dtype=float32)}
# {'predictions': array([1877.3389], dtype=float32)}
# {'predictions': array([5857.9688], dtype=float32)}
# {'predictions': array([1909.9412], dtype=float32)}
# {'predictions': array([2544.5134], dtype=float32)}
# {'predictions': array([1776.5538], dtype=float32)}
# {'predictions': array([8592.881], dtype=float32)}
# {'predictions': array([2701.2903], dtype=float32)}
# {'predictions': array([2161.9036], dtype=float32)}
# {'predictions': array([1118.8333], dtype=float32)}
# {'predictions': array([2059.3743], dtype=float32)}
# {'predictions': array([2060.326], dtype=float32)}
# {'predictions': array([1777.5493], dtype=float32)}
# {'predictions': array([1505.0564], dtype=float32)}
# {'predictions': array([1200.8325], dtype=float32)}
# {'predictions': array([5943.03], dtype=float32)}
# {'predictions': array([1562.7352], dtype=float32)}
# {'predictions': array([1970.5391], dtype=float32)}
# {'predictions': array([1898.072], dtype=float32)}
# {'predictions': array([1347.2844], dtype=float32)}
# {'predictions': array([2111.4539], dtype=float32)}
# {'predictions': array([1814.9554], dtype=float32)}
# {'predictions': array([1131.898], dtype=float32)}
# {'predictions': array([2439.9956], dtype=float32)}
# {'predictions': array([5943.03], dtype=float32)}
# {'predictions': array([1594.6406], dtype=float32)}
# {'predictions': array([2414.9397], dtype=float32)}
# {'predictions': array([2060.326], dtype=float32)}
# {'predictions': array([2038.0513], dtype=float32)}
# {'predictions': array([2233.9001], dtype=float32)}
# {'predictions': array([2769.554], dtype=float32)}
# {'predictions': array([2179.8967], dtype=float32)}
# {'predictions': array([1810.2297], dtype=float32)}
# {'predictions': array([1919.3949], dtype=float32)}
# {'predictions': array([1958.5317], dtype=float32)}
# {'predictions': array([1417.3337], dtype=float32)}
# {'predictions': array([1928.027], dtype=float32)}
# {'predictions': array([1827.0273], dtype=float32)}
# {'predictions': array([3037.3623], dtype=float32)}
# {'predictions': array([1856.8087], dtype=float32)}
# {'predictions': array([1495.7598], dtype=float32)}
# {'predictions': array([1870.169], dtype=float32)}
# {'predictions': array([1350.2245], dtype=float32)}
# {'predictions': array([1877.3389], dtype=float32)}
# {'predictions': array([3665.4905], dtype=float32)}
# {'predictions': array([1897.8691], dtype=float32)}
# {'predictions': array([1450.1504], dtype=float32)}
# {'predictions': array([1344.7471], dtype=float32)}
# {'predictions': array([2063.107], dtype=float32)}
# {'predictions': array([1716.772], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([2008.067], dtype=float32)}
# {'predictions': array([2102.3938], dtype=float32)}
# {'predictions': array([2621.7886], dtype=float32)}
# {'predictions': array([3681.386], dtype=float32)}
# {'predictions': array([1939.9253], dtype=float32)}
# {'predictions': array([1522.9252], dtype=float32)}
# {'predictions': array([1939.9253], dtype=float32)}
# {'predictions': array([1220.6921], dtype=float32)}
# {'predictions': array([2670.6355], dtype=float32)}
# {'predictions': array([4490.1646], dtype=float32)}
# {'predictions': array([2305.6157], dtype=float32)}
# {'predictions': array([1917.5286], dtype=float32)}
# {'predictions': array([4304.3994], dtype=float32)}
# {'predictions': array([2494.121], dtype=float32)}
# {'predictions': array([1465.9817], dtype=float32)}
# {'predictions': array([1742.0879], dtype=float32)}
# {'predictions': array([1840.133], dtype=float32)}
# {'predictions': array([1937.2661], dtype=float32)}
# {'predictions': array([1148.6954], dtype=float32)}
# {'predictions': array([1952.1165], dtype=float32)}
# {'predictions': array([1817.6145], dtype=float32)}
# {'predictions': array([2396.398], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([2340.1462], dtype=float32)}
# {'predictions': array([1887.8666], dtype=float32)}
# {'predictions': array([1556.32], dtype=float32)}
# {'predictions': array([2132.0413], dtype=float32)}
# {'predictions': array([2049.9202], dtype=float32)}
# {'predictions': array([1792.4805], dtype=float32)}
# {'predictions': array([1988.3293], dtype=float32)}
# {'predictions': array([1143.0963], dtype=float32)}
# {'predictions': array([1797.9578], dtype=float32)}
# {'predictions': array([1765.4775], dtype=float32)}
# {'predictions': array([1579.0121], dtype=float32)}
# {'predictions': array([1856.8087], dtype=float32)}
# {'predictions': array([2182.6343], dtype=float32)}
# {'predictions': array([2060.448], dtype=float32)}
# {'predictions': array([1487.3855], dtype=float32)}
# {'predictions': array([2495.93], dtype=float32)}
# {'predictions': array([2137.5833], dtype=float32)}
# {'predictions': array([1681.6636], dtype=float32)}
# {'predictions': array([1912.1296], dtype=float32)}
# {'predictions': array([2415.0618], dtype=float32)}
# {'predictions': array([1950.209], dtype=float32)}
# {'predictions': array([3124.168], dtype=float32)}
# {'predictions': array([3742.7356], dtype=float32)}
# {'predictions': array([1221.4271], dtype=float32)}
# {'predictions': array([1783.0266], dtype=float32)}
# {'predictions': array([2414.069], dtype=float32)}
# {'predictions': array([2136.848], dtype=float32)}
# {'predictions': array([3739.0537], dtype=float32)}
# {'predictions': array([2389.725], dtype=float32)}
# {'predictions': array([876.14514], dtype=float32)}
# {'predictions': array([1495.0513], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([2248.7505], dtype=float32)}
# {'predictions': array([7155.172], dtype=float32)}
# {'predictions': array([4483.761], dtype=float32)}
# {'predictions': array([1417.3362], dtype=float32)}
# {'predictions': array([1553.6753], dtype=float32)}
# {'predictions': array([1495.722], dtype=float32)}
# {'predictions': array([792.2959], dtype=float32)}
# {'predictions': array([1957.7964], dtype=float32)}
# {'predictions': array([1297.8872], dtype=float32)}
# {'predictions': array([4107.824], dtype=float32)}
# {'predictions': array([2769.554], dtype=float32)}
# {'predictions': array([2693.8247], dtype=float32)}
# {'predictions': array([2601.3787], dtype=float32)}
# {'predictions': array([1883.2336], dtype=float32)}
# {'predictions': array([1128.1652], dtype=float32)}
# {'predictions': array([1590.0392], dtype=float32)}
# {'predictions': array([2579.1824], dtype=float32)}
# {'predictions': array([899.6518], dtype=float32)}
# {'predictions': array([1143.0963], dtype=float32)}
# {'predictions': array([1401.7051], dtype=float32)}
# {'predictions': array([2798.4644], dtype=float32)}
# {'predictions': array([1589.304], dtype=float32)}
# {'predictions': array([1758.9208], dtype=float32)}
# {'predictions': array([1936.8865], dtype=float32)}
# {'predictions': array([1863.4031], dtype=float32)}
# {'predictions': array([1090.8374], dtype=float32)}
# {'predictions': array([4253.403], dtype=float32)}
# {'predictions': array([1125.5061], dtype=float32)}
# {'predictions': array([2176.0833], dtype=float32)}
# {'predictions': array([986.3195], dtype=float32)}
# {'predictions': array([3641.9622], dtype=float32)}
# {'predictions': array([1413.6008], dtype=float32)}
# {'predictions': array([4057.432], dtype=float32)}
# {'predictions': array([2176.0833], dtype=float32)}
# {'predictions': array([2635.9666], dtype=float32)}
# {'predictions': array([3770.008], dtype=float32)}
# {'predictions': array([1032.8], dtype=float32)}
# {'predictions': array([2156.3044], dtype=float32)}
# {'predictions': array([710.0942], dtype=float32)}
# {'predictions': array([1742.0879], dtype=float32)}
# {'predictions': array([10777.963], dtype=float32)}
# {'predictions': array([1997.604], dtype=float32)}
# {'predictions': array([2453.1824], dtype=float32)}
# {'predictions': array([1090.8374], dtype=float32)}
# {'predictions': array([2663.2917], dtype=float32)}
# {'predictions': array([3405.0413], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([1978.9973], dtype=float32)}
# {'predictions': array([1903.6711], dtype=float32)}
# {'predictions': array([2240.5615], dtype=float32)}
# {'predictions': array([2024.9865], dtype=float32)}
# {'predictions': array([1162.6337], dtype=float32)}
# {'predictions': array([1551.0164], dtype=float32)}
# {'predictions': array([2644.425], dtype=float32)}
# {'predictions': array([1817.6145], dtype=float32)}
# {'predictions': array([1393.2733], dtype=float32)}
# {'predictions': array([1464.1962], dtype=float32)}
# {'predictions': array([1601.1133], dtype=float32)}
# {'predictions': array([1621.7655], dtype=float32)}
# {'predictions': array([1716.0369], dtype=float32)}
# {'predictions': array([1388.345], dtype=float32)}
# {'predictions': array([1286.6863], dtype=float32)}
# {'predictions': array([1231.7684], dtype=float32)}
# {'predictions': array([2693.8247], dtype=float32)}
# {'predictions': array([1739.3479], dtype=float32)}
# {'predictions': array([4217.9414], dtype=float32)}
# {'predictions': array([1988.3938], dtype=float32)}
# {'predictions': array([2434.4143], dtype=float32)}
# {'predictions': array([1799.2462], dtype=float32)}
# {'predictions': array([1877.4608], dtype=float32)}
# {'predictions': array([2996.1797], dtype=float32)}
# {'predictions': array([1032.8], dtype=float32)}
# {'predictions': array([2360.937], dtype=float32)}
# {'predictions': array([2247.7002], dtype=float32)}
# {'predictions': array([2403.8635], dtype=float32)}
# {'predictions': array([1419.3218], dtype=float32)}
# {'predictions': array([1929.8933], dtype=float32)}
# {'predictions': array([1034.7239], dtype=float32)}
# {'predictions': array([4490.1646], dtype=float32)}
# {'predictions': array([2057.5076], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([1875.4727], dtype=float32)}
# {'predictions': array([1881.8877], dtype=float32)}
# {'predictions': array([1049.7194], dtype=float32)}
# {'predictions': array([2996.1797], dtype=float32)}
# {'predictions': array([1593.7288], dtype=float32)}
# {'predictions': array([1135.6306], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([2508.2595], dtype=float32)}
# {'predictions': array([1840.133], dtype=float32)}
# {'predictions': array([1288.6747], dtype=float32)}
# {'predictions': array([1042.3921], dtype=float32)}
# {'predictions': array([1515.2593], dtype=float32)}
# {'predictions': array([1135.6306], dtype=float32)}
# {'predictions': array([2881.3372], dtype=float32)}
# {'predictions': array([1652.7015], dtype=float32)}
# {'predictions': array([1809.3562], dtype=float32)}
# {'predictions': array([1377.2684], dtype=float32)}
# {'predictions': array([1520.023], dtype=float32)}
# {'predictions': array([2419.5872], dtype=float32)}
# {'predictions': array([2406.5227], dtype=float32)}
# {'predictions': array([6536.8516], dtype=float32)}
# {'predictions': array([1662.7849], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([1216.7614], dtype=float32)}
# {'predictions': array([2671.1543], dtype=float32)}
# {'predictions': array([3738.0046], dtype=float32)}
# {'predictions': array([1791.5659], dtype=float32)}
# {'predictions': array([1317.544], dtype=float32)}
# {'predictions': array([2065.0085], dtype=float32)}
# {'predictions': array([1776.5538], dtype=float32)}
# {'predictions': array([1316.6704], dtype=float32)}
# {'predictions': array([1655.3606], dtype=float32)}
# {'predictions': array([1647.8539], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1556.32], dtype=float32)}
# {'predictions': array([4057.432], dtype=float32)}
# {'predictions': array([2389.725], dtype=float32)}
# {'predictions': array([2060.448], dtype=float32)}
# {'predictions': array([1917.5286], dtype=float32)}
# {'predictions': array([2125.6497], dtype=float32)}
# {'predictions': array([1568.7139], dtype=float32)}
# {'predictions': array([1495.0247], dtype=float32)}
# {'predictions': array([2515.7249], dtype=float32)}
# {'predictions': array([2721.8206], dtype=float32)}
# {'predictions': array([5789.848], dtype=float32)}
# {'predictions': array([2948.6492], dtype=float32)}
# {'predictions': array([1270.8843], dtype=float32)}
# {'predictions': array([2388.8108], dtype=float32)}
# {'predictions': array([850.07306], dtype=float32)}
# {'predictions': array([1802.7642], dtype=float32)}
# {'predictions': array([1855.0232], dtype=float32)}
# {'predictions': array([1938.8104], dtype=float32)}
# {'predictions': array([2601.701], dtype=float32)}
# {'predictions': array([2423.279], dtype=float32)}
# {'predictions': array([1591.003], dtype=float32)}
# {'predictions': array([1000.25775], dtype=float32)}
# {'predictions': array([1752.4128], dtype=float32)}
# {'predictions': array([1309.121], dtype=float32)}
# {'predictions': array([1220.5701], dtype=float32)}
# {'predictions': array([1143.0963], dtype=float32)}
# {'predictions': array([2150.7053], dtype=float32)}
# {'predictions': array([1284.8225], dtype=float32)}
# {'predictions': array([3717.6802], dtype=float32)}
# {'predictions': array([1557.1359], dtype=float32)}
# {'predictions': array([2057.6006], dtype=float32)}
# {'predictions': array([2434.4143], dtype=float32)}
# {'predictions': array([1591.9816], dtype=float32)}
# {'predictions': array([2428.2195], dtype=float32)}
# {'predictions': array([1601.1133], dtype=float32)}
# {'predictions': array([3734.5464], dtype=float32)}
# {'predictions': array([1151.5137], dtype=float32)}
# {'predictions': array([2447.4612], dtype=float32)}
# {'predictions': array([2445.6592], dtype=float32)}
# {'predictions': array([2056.593], dtype=float32)}
# {'predictions': array([1479.1273], dtype=float32)}
# {'predictions': array([1487.3855], dtype=float32)}
# {'predictions': array([1308.3857], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([1737.6552], dtype=float32)}
# {'predictions': array([1878.3345], dtype=float32)}
# {'predictions': array([1999.6495], dtype=float32)}
# {'predictions': array([2518.384], dtype=float32)}
# {'predictions': array([1739.3479], dtype=float32)}
# {'predictions': array([1784.1415], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([1118.8333], dtype=float32)}
# {'predictions': array([1242.8884], dtype=float32)}
# {'predictions': array([4352.7285], dtype=float32)}
# {'predictions': array([1394.0249], dtype=float32)}
# {'predictions': array([1662.9996], dtype=float32)}
# {'predictions': array([1789.6993], dtype=float32)}
# {'predictions': array([1383.7411], dtype=float32)}
# {'predictions': array([2049.2495], dtype=float32)}
# {'predictions': array([1998.7761], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1794.2249], dtype=float32)}
# {'predictions': array([1627.5383], dtype=float32)}
# {'predictions': array([3036.4478], dtype=float32)}
# {'predictions': array([1174.9058], dtype=float32)}
# {'predictions': array([1401.7051], dtype=float32)}
# {'predictions': array([1595.5142], dtype=float32)}
# {'predictions': array([1495.722], dtype=float32)}
# {'predictions': array([3503.9187], dtype=float32)}
# {'predictions': array([1848.2927], dtype=float32)}
# {'predictions': array([1906.3302], dtype=float32)}
# {'predictions': array([2060.326], dtype=float32)}
# {'predictions': array([1604.927], dtype=float32)}
# {'predictions': array([1242.8884], dtype=float32)}
# {'predictions': array([1408.2046], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([1718.6958], dtype=float32)}
# {'predictions': array([2150.7053], dtype=float32)}
# {'predictions': array([1985.6704], dtype=float32)}
# {'predictions': array([1095.4436], dtype=float32)}
# {'predictions': array([1740.4219], dtype=float32)}
# {'predictions': array([1032.0647], dtype=float32)}
# {'predictions': array([3013.9705], dtype=float32)}
# {'predictions': array([427.47647], dtype=float32)}
# {'predictions': array([1709.6594], dtype=float32)}
# {'predictions': array([2174.1758], dtype=float32)}
# {'predictions': array([1681.6636], dtype=float32)}
# {'predictions': array([1727.0349], dtype=float32)}
# {'predictions': array([1700.032], dtype=float32)}
# {'predictions': array([2370.8818], dtype=float32)}
# {'predictions': array([1528.6196], dtype=float32)}
# {'predictions': array([1988.3293], dtype=float32)}
# {'predictions': array([2406.5227], dtype=float32)}
# {'predictions': array([1675.9717], dtype=float32)}
# {'predictions': array([1828.8129], dtype=float32)}
# {'predictions': array([1873.687], dtype=float32)}
# {'predictions': array([2024.9865], dtype=float32)}
# {'predictions': array([1917.5286], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([1607.9082], dtype=float32)}
# {'predictions': array([1792.4805], dtype=float32)}
# {'predictions': array([1495.0247], dtype=float32)}
# {'predictions': array([1051.6432], dtype=float32)}
# {'predictions': array([1681.6636], dtype=float32)}
# {'predictions': array([1834.6147], dtype=float32)}
# {'predictions': array([1313.7703], dtype=float32)}
# {'predictions': array([3329.39], dtype=float32)}
# {'predictions': array([1357.8119], dtype=float32)}
# {'predictions': array([1822.3428], dtype=float32)}
# {'predictions': array([2337.4255], dtype=float32)}
# {'predictions': array([1310.0808], dtype=float32)}
# {'predictions': array([1697.3298], dtype=float32)}
# {'predictions': array([1718.6958], dtype=float32)}
# {'predictions': array([2331.826], dtype=float32)}
# {'predictions': array([3286.6135], dtype=float32)}
# {'predictions': array([571.9817], dtype=float32)}
# {'predictions': array([793.0891], dtype=float32)}
# {'predictions': array([2378.405], dtype=float32)}
# {'predictions': array([1607.5859], dtype=float32)}
# {'predictions': array([2547.5757], dtype=float32)}
# {'predictions': array([4491.0386], dtype=float32)}
# {'predictions': array([1202.0281], dtype=float32)}
# {'predictions': array([2246.965], dtype=float32)}
# {'predictions': array([1309.121], dtype=float32)}
# {'predictions': array([2424.3127], dtype=float32)}
# {'predictions': array([2709.873], dtype=float32)}
# {'predictions': array([2660.3513], dtype=float32)}
# {'predictions': array([1587.4706], dtype=float32)}
# {'predictions': array([2415.0618], dtype=float32)}
# {'predictions': array([5791.602], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([1316.6704], dtype=float32)}
# {'predictions': array([1666.6398], dtype=float32)}
# {'predictions': array([1288.6747], dtype=float32)}
# {'predictions': array([2247.877], dtype=float32)}
# {'predictions': array([1715.0438], dtype=float32)}
# {'predictions': array([2196.5725], dtype=float32)}
# {'predictions': array([2472.92], dtype=float32)}
# {'predictions': array([2152.7288], dtype=float32)}
# {'predictions': array([1148.6954], dtype=float32)}
# {'predictions': array([2633.1074], dtype=float32)}
# {'predictions': array([2403.8635], dtype=float32)}
# {'predictions': array([3363.928], dtype=float32)}
# {'predictions': array([1624.5054], dtype=float32)}
# {'predictions': array([1780.4086], dtype=float32)}
# {'predictions': array([2286.159], dtype=float32)}
# {'predictions': array([1948.4646], dtype=float32)}
# {'predictions': array([1935.4926], dtype=float32)}
# {'predictions': array([1783.0266], dtype=float32)}
# {'predictions': array([2439.9956], dtype=float32)}
# {'predictions': array([1616.3398], dtype=float32)}
# {'predictions': array([1661.8333], dtype=float32)}
# {'predictions': array([1716.9104], dtype=float32)}
# {'predictions': array([2721.8206], dtype=float32)}
# {'predictions': array([3288.332], dtype=float32)}
# {'predictions': array([1224.1027], dtype=float32)}
# {'predictions': array([1784.1415], dtype=float32)}
# {'predictions': array([1623.632], dtype=float32)}
# {'predictions': array([1829.6863], dtype=float32)}
# {'predictions': array([2258.1633], dtype=float32)}
# {'predictions': array([4035.8281], dtype=float32)}
# {'predictions': array([1216.7614], dtype=float32)}
# {'predictions': array([1130.0316], dtype=float32)}
# {'predictions': array([2380.2712], dtype=float32)}
# {'predictions': array([1607.5859], dtype=float32)}
# {'predictions': array([1055.376], dtype=float32)}
# {'predictions': array([2316.8142], dtype=float32)}
# {'predictions': array([4303.526], dtype=float32)}
# {'predictions': array([1378.2203], dtype=float32)}
# {'predictions': array([2372.013], dtype=float32)}
# {'predictions': array([1775.7183], dtype=float32)}
# {'predictions': array([1051.6432], dtype=float32)}
# {'predictions': array([1966.174], dtype=float32)}
# {'predictions': array([1495.7598], dtype=float32)}
# {'predictions': array([1055.376], dtype=float32)}
# {'predictions': array([1447.4913], dtype=float32)}
# {'predictions': array([1809.3562], dtype=float32)}
# {'predictions': array([4303.526], dtype=float32)}
# {'predictions': array([4491.2793], dtype=float32)}
# {'predictions': array([1992.0623], dtype=float32)}
# {'predictions': array([1780.3674], dtype=float32)}
# {'predictions': array([1659.2668], dtype=float32)}
# {'predictions': array([2334.485], dtype=float32)}
# {'predictions': array([2407.5962], dtype=float32)}
# {'predictions': array([1947.5645], dtype=float32)}
# {'predictions': array([2073.6052], dtype=float32)}
# {'predictions': array([1967.0066], dtype=float32)}
# {'predictions': array([991.91864], dtype=float32)}
# {'predictions': array([1363.3303], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([1413.7227], dtype=float32)}
# {'predictions': array([2620.243], dtype=float32)}
# {'predictions': array([1877.4608], dtype=float32)}
# {'predictions': array([1416.6362], dtype=float32)}
# {'predictions': array([2406.5227], dtype=float32)}
# {'predictions': array([2596.8943], dtype=float32)}
# {'predictions': array([2400.009], dtype=float32)}
# {'predictions': array([2001.6089], dtype=float32)}
# {'predictions': array([1410.8634], dtype=float32)}
# {'predictions': array([2276.7463], dtype=float32)}
# {'predictions': array([22.420717], dtype=float32)}
# {'predictions': array([1690.9026], dtype=float32)}
# {'predictions': array([2050.0422], dtype=float32)}
# {'predictions': array([3037.1829], dtype=float32)}
# {'predictions': array([2531.4487], dtype=float32)}
# {'predictions': array([3175.5037], dtype=float32)}
# {'predictions': array([2456.9934], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([4107.824], dtype=float32)}
# {'predictions': array([2586.648], dtype=float32)}
# {'predictions': array([1146.0364], dtype=float32)}
# {'predictions': array([1749.4315], dtype=float32)}
# {'predictions': array([2412.1218], dtype=float32)}
# {'predictions': array([1715.085], dtype=float32)}
# {'predictions': array([5234.344], dtype=float32)}
# {'predictions': array([2227.2273], dtype=float32)}
# {'predictions': array([1442.592], dtype=float32)}
# {'predictions': array([2508.2595], dtype=float32)}
# {'predictions': array([1802.7642], dtype=float32)}
# {'predictions': array([2350.409], dtype=float32)}
# {'predictions': array([2326.2268], dtype=float32)}
# {'predictions': array([4858.407], dtype=float32)}
# {'predictions': array([1442.592], dtype=float32)}
# {'predictions': array([2437.1365], dtype=float32)}
# {'predictions': array([1681.6636], dtype=float32)}
# {'predictions': array([5789.848], dtype=float32)}
# {'predictions': array([2817.0066], dtype=float32)}
# {'predictions': array([4069.3657], dtype=float32)}
# {'predictions': array([2709.2175], dtype=float32)}
# {'predictions': array([2179.8967], dtype=float32)}
# {'predictions': array([1503.1901], dtype=float32)}
# {'predictions': array([1849.3431], dtype=float32)}
# {'predictions': array([1775.943], dtype=float32)}
# {'predictions': array([1689.1292], dtype=float32)}
# {'predictions': array([1731.8823], dtype=float32)}
# {'predictions': array([2079.7825], dtype=float32)}
# {'predictions': array([2079.7825], dtype=float32)}
# {'predictions': array([1619.1064], dtype=float32)}
# {'predictions': array([1036.712], dtype=float32)}
# {'predictions': array([850.9471], dtype=float32)}
# {'predictions': array([10777.963], dtype=float32)}
# {'predictions': array([3738.0046], dtype=float32)}
# {'predictions': array([857.48114], dtype=float32)}
# {'predictions': array([2621.8518], dtype=float32)}
# {'predictions': array([1712.4259], dtype=float32)}
# {'predictions': array([1827.7625], dtype=float32)}
# {'predictions': array([5488.6826], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([1775.943], dtype=float32)}
# {'predictions': array([4303.526], dtype=float32)}
# {'predictions': array([2076.1716], dtype=float32)}
# {'predictions': array([1158.9009], dtype=float32)}
# {'predictions': array([1967.0066], dtype=float32)}
# {'predictions': array([2537.2483], dtype=float32)}
# {'predictions': array([2570.6428], dtype=float32)}
# {'predictions': array([1554.3961], dtype=float32)}
# {'predictions': array([1095.4436], dtype=float32)}
# {'predictions': array([2360.937], dtype=float32)}
# {'predictions': array([2621.7886], dtype=float32)}
# {'predictions': array([1522.9252], dtype=float32)}
# {'predictions': array([1129.239], dtype=float32)}
# {'predictions': array([1709.4447], dtype=float32)}
# {'predictions': array([1514.5886], dtype=float32)}
# {'predictions': array([1689.6497], dtype=float32)}
# {'predictions': array([1799.0314], dtype=float32)}
# {'predictions': array([2342.9434], dtype=float32)}
# {'predictions': array([1898.072], dtype=float32)}
# {'predictions': array([5943.03], dtype=float32)}
# {'predictions': array([2709.2175], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([879.93536], dtype=float32)}
# {'predictions': array([2079.7825], dtype=float32)}
# {'predictions': array([2880.4636], dtype=float32)}
# {'predictions': array([2570.6428], dtype=float32)}
# {'predictions': array([1593.7288], dtype=float32)}
# {'predictions': array([2335.5996], dtype=float32)}
# {'predictions': array([1716.772], dtype=float32)}
# {'predictions': array([1986.463], dtype=float32)}
# {'predictions': array([1961.6221], dtype=float32)}
# {'predictions': array([2708.4822], dtype=float32)}
# {'predictions': array([1766.2291], dtype=float32)}
# {'predictions': array([2248.9534], dtype=float32)}
# {'predictions': array([1930.5933], dtype=float32)}
# {'predictions': array([1950.209], dtype=float32)}
# {'predictions': array([2022.0464], dtype=float32)}
# {'predictions': array([2494.121], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([1400.658], dtype=float32)}
# {'predictions': array([1502.1947], dtype=float32)}
# {'predictions': array([1877.3389], dtype=float32)}
# {'predictions': array([1649.9349], dtype=float32)}
# {'predictions': array([7155.172], dtype=float32)}
# {'predictions': array([5988.0825], dtype=float32)}
# {'predictions': array([4057.432], dtype=float32)}
# {'predictions': array([1922.213], dtype=float32)}
# {'predictions': array([2412.1218], dtype=float32)}
# {'predictions': array([2196.5725], dtype=float32)}
# {'predictions': array([2010.7262], dtype=float32)}
# {'predictions': array([1890.4038], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([1916.655], dtype=float32)}
# {'predictions': array([2128.3086], dtype=float32)}
# {'predictions': array([1358.5471], dtype=float32)}
# {'predictions': array([2175.9614], dtype=float32)}
# {'predictions': array([2612.8323], dtype=float32)}
# {'predictions': array([1345.5398], dtype=float32)}
# {'predictions': array([2073.6052], dtype=float32)}
# {'predictions': array([790.3487], dtype=float32)}
# {'predictions': array([987.19305], dtype=float32)}
# {'predictions': array([1714.092], dtype=float32)}
# {'predictions': array([2547.5757], dtype=float32)}
# {'predictions': array([1718.6958], dtype=float32)}
# {'predictions': array([2607.1782], dtype=float32)}
# {'predictions': array([2434.4143], dtype=float32)}
# {'predictions': array([3820.382], dtype=float32)}
# {'predictions': array([2196.5725], dtype=float32)}
# {'predictions': array([2249.6238], dtype=float32)}
# {'predictions': array([791.3005], dtype=float32)}
# {'predictions': array([1971.6538], dtype=float32)}
# {'predictions': array([1284.8225], dtype=float32)}
# {'predictions': array([1288.6747], dtype=float32)}
# {'predictions': array([1913.6737], dtype=float32)}
# {'predictions': array([1866.9568], dtype=float32)}
# {'predictions': array([2247.7002], dtype=float32)}
# {'predictions': array([2987.991], dtype=float32)}
# {'predictions': array([1419.2954], dtype=float32)}
# {'predictions': array([1866.9568], dtype=float32)}
# {'predictions': array([1383.7411], dtype=float32)}
# {'predictions': array([1421.1042], dtype=float32)}
# {'predictions': array([1837.1519], dtype=float32)}
# {'predictions': array([1441.6345], dtype=float32)}
# {'predictions': array([2073.5127], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([1682.3987], dtype=float32)}
# {'predictions': array([2135.8962], dtype=float32)}
# {'predictions': array([1826.9464], dtype=float32)}
# {'predictions': array([1589.0795], dtype=float32)}
# {'predictions': array([1151.5137], dtype=float32)}
# {'predictions': array([1818.8102], dtype=float32)}
# {'predictions': array([2439.9956], dtype=float32)}
# {'predictions': array([2614.7131], dtype=float32)}
# {'predictions': array([1051.6432], dtype=float32)}
# {'predictions': array([1883.8115], dtype=float32)}
# {'predictions': array([1594.6406], dtype=float32)}
# {'predictions': array([1876.2886], dtype=float32)}
# {'predictions': array([980.7203], dtype=float32)}
# {'predictions': array([1400.658], dtype=float32)}
# {'predictions': array([2528.9114], dtype=float32)}
# {'predictions': array([1221.4271], dtype=float32)}
# {'predictions': array([847.4141], dtype=float32)}
# {'predictions': array([1579.7473], dtype=float32)}
# {'predictions': array([2794.6216], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([2135.8962], dtype=float32)}
# {'predictions': array([1776.6184], dtype=float32)}
# {'predictions': array([2880.4636], dtype=float32)}
# {'predictions': array([1338.155], dtype=float32)}
# {'predictions': array([2334.485], dtype=float32)}
# {'predictions': array([1514.4237], dtype=float32)}
# {'predictions': array([2439.9956], dtype=float32)}
# {'predictions': array([1284.1494], dtype=float32)}
# {'predictions': array([2057.5076], dtype=float32)}
# {'predictions': array([3081.3103], dtype=float32)}
# {'predictions': array([2178.0305], dtype=float32)}
# {'predictions': array([2419.5872], dtype=float32)}
# {'predictions': array([3272.2517], dtype=float32)}
# {'predictions': array([1914.7886], dtype=float32)}
# {'predictions': array([2250.4346], dtype=float32)}
# {'predictions': array([1709.6594], dtype=float32)}
# {'predictions': array([1224.2246], dtype=float32)}
# {'predictions': array([1919.273], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1051.6432], dtype=float32)}
# {'predictions': array([2542.769], dtype=float32)}
# {'predictions': array([1500.409], dtype=float32)}
# {'predictions': array([378.82913], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([2497.0613], dtype=float32)}
# {'predictions': array([2150.7053], dtype=float32)}
# {'predictions': array([6651.014], dtype=float32)}
# {'predictions': array([2406.5227], dtype=float32)}
# {'predictions': array([2050.0422], dtype=float32)}
# {'predictions': array([1270.0918], dtype=float32)}
# {'predictions': array([1401.7051], dtype=float32)}
# {'predictions': array([3037.2402], dtype=float32)}
# {'predictions': array([2439.9956], dtype=float32)}
# {'predictions': array([1447.4913], dtype=float32)}
# {'predictions': array([3081.3103], dtype=float32)}
# {'predictions': array([1603.1016], dtype=float32)}
# {'predictions': array([1709.6594], dtype=float32)}
# {'predictions': array([1856.8087], dtype=float32)}
# {'predictions': array([2197.365], dtype=float32)}
# {'predictions': array([2005.0695], dtype=float32)}
# {'predictions': array([1961.3265], dtype=float32)}
# {'predictions': array([3364.7317], dtype=float32)}
# {'predictions': array([1999.6495], dtype=float32)}
# {'predictions': array([3211.2761], dtype=float32)}
# {'predictions': array([1756.3192], dtype=float32)}
# {'predictions': array([1374.6094], dtype=float32)}
# {'predictions': array([1998.9497], dtype=float32)}
# {'predictions': array([1045.0513], dtype=float32)}
# {'predictions': array([1972.6467], dtype=float32)}
# {'predictions': array([1131.898], dtype=float32)}
# {'predictions': array([1463.3225], dtype=float32)}
# {'predictions': array([1818.8102], dtype=float32)}
# {'predictions': array([1847.5575], dtype=float32)}
# {'predictions': array([1582.7449], dtype=float32)}
# {'predictions': array([2354.264], dtype=float32)}
# {'predictions': array([2357.8171], dtype=float32)}
# {'predictions': array([2247.8384], dtype=float32)}
# {'predictions': array([1042.3921], dtype=float32)}
# {'predictions': array([1501.5239], dtype=float32)}
# ...
# {'predictions': array([1312.0232], dtype=float32)}
# {'predictions': array([850.9471], dtype=float32)}
# {'predictions': array([1594.8434], dtype=float32)}
# {'predictions': array([2837.659], dtype=float32)}
# {'predictions': array([1473.4062], dtype=float32)}
# {'predictions': array([1727.0349], dtype=float32)}
# {'predictions': array([1503.1901], dtype=float32)}
# {'predictions': array([687.6976], dtype=float32)}
# {'predictions': array([1597.5024], dtype=float32)}
# {'predictions': array([2133.237], dtype=float32)}
# {'predictions': array([1579.7473], dtype=float32)}
# {'predictions': array([1871.8208], dtype=float32)}
# {'predictions': array([2822.6057], dtype=float32)}
# {'predictions': array([1154.1729], dtype=float32)}
# {'predictions': array([2124.5183], dtype=float32)}
# {'predictions': array([2801.3523], dtype=float32)}
# {'predictions': array([1978.9401], dtype=float32)}
# {'predictions': array([2334.485], dtype=float32)}
# {'predictions': array([1177.5648], dtype=float32)}
# {'predictions': array([1589.0795], dtype=float32)}
# {'predictions': array([1216.7614], dtype=float32)}
# {'predictions': array([2152.7288], dtype=float32)}
# {'predictions': array([2614.7131], dtype=float32)}
# {'predictions': array([1373.5356], dtype=float32)}
# {'predictions': array([1309.121], dtype=float32)}
# {'predictions': array([1940.0037], dtype=float32)}
# {'predictions': array([1687.0481], dtype=float32)}
# {'predictions': array([1332.3533], dtype=float32)}
# {'predictions': array([3363.928], dtype=float32)}
# {'predictions': array([2388.8108], dtype=float32)}
# {'predictions': array([1682.3987], dtype=float32)}
# {'predictions': array([3284.42], dtype=float32)}
# {'predictions': array([1890.5256], dtype=float32)}
# {'predictions': array([3085.338], dtype=float32)}
# {'predictions': array([2249.6238], dtype=float32)}
# {'predictions': array([2056.634], dtype=float32)}
# {'predictions': array([1415.6699], dtype=float32)}
# {'predictions': array([2370.8818], dtype=float32)}
# {'predictions': array([991.91864], dtype=float32)}
# {'predictions': array([2050.0422], dtype=float32)}
# {'predictions': array([1220.6921], dtype=float32)}
# {'predictions': array([1589.0795], dtype=float32)}
# {'predictions': array([2249.6238], dtype=float32)}
# {'predictions': array([1261.7258], dtype=float32)}
# {'predictions': array([1809.0986], dtype=float32)}
# {'predictions': array([1937.2661], dtype=float32)}
# {'predictions': array([2134.9814], dtype=float32)}
# {'predictions': array([1877.4608], dtype=float32)}
# {'predictions': array([2086.4553], dtype=float32)}
# {'predictions': array([2136.848], dtype=float32)}
# {'predictions': array([1986.463], dtype=float32)}
# {'predictions': array([2060.326], dtype=float32)}
# {'predictions': array([2451.1365], dtype=float32)}
# {'predictions': array([1659.2668], dtype=float32)}
# {'predictions': array([2073.6052], dtype=float32)}
# {'predictions': array([2335.5996], dtype=float32)}
# {'predictions': array([2133.237], dtype=float32)}
# {'predictions': array([1652.7015], dtype=float32)}
# {'predictions': array([1676.6423], dtype=float32)}
# {'predictions': array([1687.0481], dtype=float32)}
# {'predictions': array([2107.9004], dtype=float32)}
# {'predictions': array([1802.7642], dtype=float32)}
# {'predictions': array([1556.4008], dtype=float32)}
# {'predictions': array([2050.0422], dtype=float32)}
# {'predictions': array([2439.9956], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([8407.988], dtype=float32)}
# {'predictions': array([2350.409], dtype=float32)}
# {'predictions': array([2356.5273], dtype=float32)}
# {'predictions': array([850.07306], dtype=float32)}
# {'predictions': array([2436.263], dtype=float32)}
# {'predictions': array([2217.1025], dtype=float32)}
# {'predictions': array([1046.1249], dtype=float32)}
# {'predictions': array([2176.0833], dtype=float32)}
# {'predictions': array([1747.5078], dtype=float32)}
# {'predictions': array([2531.5706], dtype=float32)}
# {'predictions': array([3641.9622], dtype=float32)}
# {'predictions': array([1740.3142], dtype=float32)}
# {'predictions': array([1829.6863], dtype=float32)}
# {'predictions': array([1955.8083], dtype=float32)}
# {'predictions': array([1691.6954], dtype=float32)}
# {'predictions': array([10777.963], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([842.42816], dtype=float32)}
# {'predictions': array([1143.0963], dtype=float32)}
# {'predictions': array([1314.6823], dtype=float32)}
# {'predictions': array([1740.4219], dtype=float32)}
# {'predictions': array([1221.5654], dtype=float32)}
# {'predictions': array([2334.485], dtype=float32)}
# {'predictions': array([1463.3225], dtype=float32)}
# {'predictions': array([2701.2903], dtype=float32)}
# {'predictions': array([4253.403], dtype=float32)}
# {'predictions': array([4011.5076], dtype=float32)}
# {'predictions': array([2629.575], dtype=float32)}
# {'predictions': array([4303.526], dtype=float32)}
# {'predictions': array([2809.541], dtype=float32)}
# {'predictions': array([1484.7263], dtype=float32)}
# {'predictions': array([1497.7102], dtype=float32)}
# {'predictions': array([850.07306], dtype=float32)}
# {'predictions': array([5229.2666], dtype=float32)}
# {'predictions': array([2436.263], dtype=float32)}
# {'predictions': array([1987.4559], dtype=float32)}
# {'predictions': array([3286.6135], dtype=float32)}
# {'predictions': array([1042.3921], dtype=float32)}
# {'predictions': array([1654.568], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([1791.5659], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([1158.9009], dtype=float32)}
# {'predictions': array([2534.389], dtype=float32)}
# {'predictions': array([830.4947], dtype=float32)}
# {'predictions': array([2062.985], dtype=float32)}
# {'predictions': array([2146.9724], dtype=float32)}
# {'predictions': array([1701.0273], dtype=float32)}
# {'predictions': array([4107.824], dtype=float32)}
# {'predictions': array([1218.7037], dtype=float32)}
# {'predictions': array([2495.3167], dtype=float32)}
# {'predictions': array([2008.067], dtype=float32)}
# {'predictions': array([1131.898], dtype=float32)}
# {'predictions': array([1990.1957], dtype=float32)}
# {'predictions': array([1551.7944], dtype=float32)}
# {'predictions': array([2375.7458], dtype=float32)}
# {'predictions': array([1987.4559], dtype=float32)}
# {'predictions': array([203.40083], dtype=float32)}
# {'predictions': array([1000.25775], dtype=float32)}
# {'predictions': array([2881.3372], dtype=float32)}
# {'predictions': array([2003.2606], dtype=float32)}
# {'predictions': array([1652.7015], dtype=float32)}
# {'predictions': array([1682.3987], dtype=float32)}
# {'predictions': array([3820.885], dtype=float32)}
# {'predictions': array([1046.1249], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([568.19086], dtype=float32)}
# {'predictions': array([2407.5962], dtype=float32)}
# {'predictions': array([2453.1824], dtype=float32)}
# {'predictions': array([2049.9202], dtype=float32)}
# {'predictions': array([2347.75], dtype=float32)}
# {'predictions': array([1839.0182], dtype=float32)}
# {'predictions': array([2160.0374], dtype=float32)}
# {'predictions': array([4374.7183], dtype=float32)}
# {'predictions': array([1896.8188], dtype=float32)}
# {'predictions': array([1492.0537], dtype=float32)}
# {'predictions': array([3742.634], dtype=float32)}
# {'predictions': array([2243.9675], dtype=float32)}
# {'predictions': array([710.0942], dtype=float32)}
# {'predictions': array([1593.97], dtype=float32)}
# {'predictions': array([2398.935], dtype=float32)}
# {'predictions': array([1397.999], dtype=float32)}
# {'predictions': array([1895.1318], dtype=float32)}
# {'predictions': array([2055.6414], dtype=float32)}
# {'predictions': array([7842.313], dtype=float32)}
# {'predictions': array([2102.301], dtype=float32)}
# {'predictions': array([1916.614], dtype=float32)}
# {'predictions': array([1826.9464], dtype=float32)}
# {'predictions': array([2212.2961], dtype=float32)}
# {'predictions': array([1909.2703], dtype=float32)}
# {'predictions': array([1847.5575], dtype=float32)}
# {'predictions': array([1525.787], dtype=float32)}
# {'predictions': array([1896.0837], dtype=float32)}
# {'predictions': array([1338.9452], dtype=float32)}
# {'predictions': array([2248.9534], dtype=float32)}
# {'predictions': array([1889.4106], dtype=float32)}
# {'predictions': array([1935.4926], dtype=float32)}
# {'predictions': array([1737.6552], dtype=float32)}
# {'predictions': array([1809.3562], dtype=float32)}
# {'predictions': array([2331.826], dtype=float32)}
# {'predictions': array([2570.6428], dtype=float32)}
# {'predictions': array([2100.3127], dtype=float32)}
# {'predictions': array([1950.209], dtype=float32)}
# {'predictions': array([2433.6038], dtype=float32)}
# {'predictions': array([4128.336], dtype=float32)}
# {'predictions': array([1838.3475], dtype=float32)}
# {'predictions': array([2848.735], dtype=float32)}
# {'predictions': array([2716.2214], dtype=float32)}
# {'predictions': array([1515.2593], dtype=float32)}
# {'predictions': array([2182.556], dtype=float32)}
# {'predictions': array([1913.7957], dtype=float32)}
# {'predictions': array([4818.3325], dtype=float32)}
# {'predictions': array([1890.4038], dtype=float32)}
# {'predictions': array([1727.0349], dtype=float32)}
# {'predictions': array([6457.2803], dtype=float32)}
# {'predictions': array([2286.281], dtype=float32)}
# {'predictions': array([1551.0164], dtype=float32)}
# {'predictions': array([1613.1277], dtype=float32)}
# {'predictions': array([1270.0107], dtype=float32)}
# {'predictions': array([1857.6821], dtype=float32)}
# {'predictions': array([1715.3052], dtype=float32)}
# {'predictions': array([1822.3428], dtype=float32)}
# {'predictions': array([3137.3025], dtype=float32)}
# {'predictions': array([5231.1147], dtype=float32)}
# {'predictions': array([3288.332], dtype=float32)}
# {'predictions': array([3923.8445], dtype=float32)}
# {'predictions': array([1430.4937], dtype=float32)}
# {'predictions': array([1032.0647], dtype=float32)}
# {'predictions': array([1373.5356], dtype=float32)}
# {'predictions': array([2578.1086], dtype=float32)}
# {'predictions': array([1601.1133], dtype=float32)}
# {'predictions': array([1137.4971], dtype=float32)}
# {'predictions': array([1719.7266], dtype=float32)}
# {'predictions': array([1992.265], dtype=float32)}
# {'predictions': array([1877.4608], dtype=float32)}
# {'predictions': array([2254.6453], dtype=float32)}
# {'predictions': array([1401.7051], dtype=float32)}
# {'predictions': array([2352.3972], dtype=float32)}
# {'predictions': array([4015.2405], dtype=float32)}
# {'predictions': array([2990.6501], dtype=float32)}
# {'predictions': array([1771.7709], dtype=float32)}
# {'predictions': array([4606.069], dtype=float32)}
# {'predictions': array([1856.8087], dtype=float32)}
# {'predictions': array([1553.6609], dtype=float32)}
# {'predictions': array([1681.3799], dtype=float32)}
# {'predictions': array([1808.3634], dtype=float32)}
# {'predictions': array([2190.0215], dtype=float32)}
# {'predictions': array([1288.6747], dtype=float32)}
# {'predictions': array([2403.8635], dtype=float32)}
# {'predictions': array([2716.2214], dtype=float32)}
# {'predictions': array([1681.3799], dtype=float32)}
# {'predictions': array([2809.541], dtype=float32)}
# {'predictions': array([1564.081], dtype=float32)}
# {'predictions': array([1623.8055], dtype=float32)}
# {'predictions': array([1957.7964], dtype=float32)}
# {'predictions': array([1687.7834], dtype=float32)}
# {'predictions': array([1148.6954], dtype=float32)}
# {'predictions': array([1588.344], dtype=float32)}
# {'predictions': array([1883.2336], dtype=float32)}
# {'predictions': array([1828.8129], dtype=float32)}
# {'predictions': array([1775.6255], dtype=float32)}
# {'predictions': array([2219.7617], dtype=float32)}
# {'predictions': array([1712.1682], dtype=float32)}
# {'predictions': array([2126.4421], dtype=float32)}
# {'predictions': array([1976.3384], dtype=float32)}
# {'predictions': array([2417.5989], dtype=float32)}
# {'predictions': array([2190.9731], dtype=float32)}
# {'predictions': array([1317.544], dtype=float32)}
# {'predictions': array([2240.4138], dtype=float32)}
# {'predictions': array([1771.2502], dtype=float32)}
# {'predictions': array([4667.741], dtype=float32)}
# {'predictions': array([4858.3623], dtype=float32)}
# {'predictions': array([1715.9584], dtype=float32)}
# {'predictions': array([1936.1897], dtype=float32)}
# {'predictions': array([2180.632], dtype=float32)}
# {'predictions': array([1495.0247], dtype=float32)}
# {'predictions': array([1828.8129], dtype=float32)}
# {'predictions': array([2406.5227], dtype=float32)}
# {'predictions': array([2996.1797], dtype=float32)}
# {'predictions': array([1914.7886], dtype=float32)}
# {'predictions': array([1782.3558], dtype=float32)}
# {'predictions': array([3921.1858], dtype=float32)}
# {'predictions': array([1690.9026], dtype=float32)}
# {'predictions': array([1909.9412], dtype=float32)}
# {'predictions': array([1802.979], dtype=float32)}
# {'predictions': array([2001.6089], dtype=float32)}
# {'predictions': array([1686.0363], dtype=float32)}
# {'predictions': array([716.7668], dtype=float32)}
# {'predictions': array([2796.476], dtype=float32)}
# {'predictions': array([1140.4373], dtype=float32)}
# {'predictions': array([941.40424], dtype=float32)}
# {'predictions': array([1749.7537], dtype=float32)}
# {'predictions': array([2174.911], dtype=float32)}
# {'predictions': array([1827.0273], dtype=float32)}
# {'predictions': array([1572.325], dtype=float32)}
# {'predictions': array([1784.3151], dtype=float32)}
# {'predictions': array([1272.7506], dtype=float32)}
# {'predictions': array([1589.0795], dtype=float32)}
# {'predictions': array([2693.8247], dtype=float32)}
# {'predictions': array([1965.262], dtype=float32)}
# {'predictions': array([1835.4858], dtype=float32)}
# {'predictions': array([1137.4971], dtype=float32)}
# {'predictions': array([2124.576], dtype=float32)}
# {'predictions': array([1495.7598], dtype=float32)}
# {'predictions': array([2138.7144], dtype=float32)}
# {'predictions': array([2434.4773], dtype=float32)}
# {'predictions': array([1413.6008], dtype=float32)}
# {'predictions': array([1515.5549], dtype=float32)}
# {'predictions': array([2492.197], dtype=float32)}
# {'predictions': array([1360.471], dtype=float32)}
# {'predictions': array([2247.7002], dtype=float32)}
# {'predictions': array([1620.9728], dtype=float32)}
# {'predictions': array([1090.8374], dtype=float32)}
# {'predictions': array([1955.8083], dtype=float32)}
# {'predictions': array([850.9471], dtype=float32)}
# {'predictions': array([2622.9019], dtype=float32)}
# {'predictions': array([1272.7506], dtype=float32)}
# {'predictions': array([1991.2695], dtype=float32)}
# {'predictions': array([1913.6737], dtype=float32)}
# {'predictions': array([1911.0149], dtype=float32)}
# {'predictions': array([14941.226], dtype=float32)}
# {'predictions': array([1042.3921], dtype=float32)}
# {'predictions': array([1809.0986], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([3738.5737], dtype=float32)}
# {'predictions': array([1571.3728], dtype=float32)}
# {'predictions': array([1279.3428], dtype=float32)}
# {'predictions': array([1669.334], dtype=float32)}
# {'predictions': array([1814.9554], dtype=float32)}
# {'predictions': array([1845.7323], dtype=float32)}
# {'predictions': array([1146.0364], dtype=float32)}
# {'predictions': array([1906.3302], dtype=float32)}
# {'predictions': array([1955.8083], dtype=float32)}
# {'predictions': array([3082.1147], dtype=float32)}
# {'predictions': array([1185.3234], dtype=float32)}
# {'predictions': array([2060.326], dtype=float32)}
# {'predictions': array([2428.2195], dtype=float32)}
# {'predictions': array([3716.6182], dtype=float32)}
# {'predictions': array([4377.32], dtype=float32)}
# {'predictions': array([2048.1184], dtype=float32)}
# {'predictions': array([3081.3103], dtype=float32)}
# {'predictions': array([1045.0511], dtype=float32)}
# {'predictions': array([1095.4436], dtype=float32)}
# {'predictions': array([4858.3623], dtype=float32)}
# {'predictions': array([1689.9484], dtype=float32)}
# {'predictions': array([1898.072], dtype=float32)}
# {'predictions': array([1579.0121], dtype=float32)}
# {'predictions': array([2299.2239], dtype=float32)}
# {'predictions': array([1826.9463], dtype=float32)}

# %%
df_test.head(15)
# Out:
#           State  BuiltUpSize  RentalPerMth  NoOfBedroom        Furnishing  \
# 39951  SELANGOR         1810          2000            3   Fully Furnished
# 40892  SELANGOR          700          2000            3   Fully Furnished
# 22234  SELANGOR          990          2000            3  Partly Furnished
# 36830  SELANGOR          720           900            3       Unfurnished
# 52857  SELANGOR          650           650            3       Unfurnished
# 45414  SELANGOR         1044          1300            3  Partly Furnished
# 37563  SELANGOR          883          1000            3  Partly Furnished
# 53526  SELANGOR          916           950            3       Unfurnished
# 44233  SELANGOR          990          3200            2   Fully Furnished
# 39663  SELANGOR          707          1500            1  Partly Furnished
# 34999  SELANGOR          450          1750            3   Fully Furnished
# 44808  SELANGOR         2400          3500            4   Fully Furnished
# 45220  SELANGOR         1320          2300            3  Partly Furnished
# 50562  SELANGOR         1065          2500            2       Unfurnished
# 40805  SELANGOR          986          1500            3   Fully Furnished
#
#                    PropertyType
# 39951  4-STY TERRACE/LINK HOUSE
# 40892        SERVICED RESIDENCE
# 22234               CONDOMINIUM
# 36830        SERVICED RESIDENCE
# 52857                      FLAT
# 45414        SERVICED RESIDENCE
# 37563                 APARTMENT
# 53526                 APARTMENT
# 44233               CONDOMINIUM
# 39663        SERVICED RESIDENCE
# 34999        SERVICED RESIDENCE
# 44808               CONDOMINIUM
# 45220        SERVICED RESIDENCE
# 50562        SERVICED RESIDENCE
# 40805               CONDOMINIUM
