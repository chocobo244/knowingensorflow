# %% [markdown]
# # Lab - CarPark Vacancy
# Reference: Dataset was extracted from one of the KlangValley shopping mall (updated to Nov 2018)
#
# Exercise:
# 1. Predict the carpark vacant status in Zone A.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil

# %% [markdown]
# ## Reading dataset

# %%
df_sep = pd.read_csv("./data/carpark/2018-09/vacantBays_2018-9.csv")
print('Sep dataset: {}'.format(df_sep.shape))

df_oct = pd.read_csv("./data/carpark/2018-10/vacantBays_2018-10.csv")
#df_oct.dtypes
print('Oct dataset: {}'.format(df_oct.shape))

df_nov = pd.read_csv("./data/carpark/2018-11/vacantBays_2018-11.csv")
print('Nov dataset: {}'.format(df_nov.shape))

df = df_sep.append(df_oct.append(df_nov))
print('Sep - Oct dataset: {}'.format(df.shape))
# Out:
# Sep dataset: (1051, 9)
# Oct dataset: (2969, 9)
# Nov dataset: (2871, 9)
# Sep - Oct dataset: (6891, 9)

# %% [markdown]
# ## Cleanup & prepare data metadata

# %%
#Cleanup numbers

cleanup_nums = {"A": {"FULL": 0},
                "B": {"FULL": 0},
                "C": {"FULL": 0},
                "G": {"FULL": 0},
                "H": {"FULL": 0},
                "P": {"FULL": 0},
                "U": {"FULL": 0},
               }

df.replace(cleanup_nums, inplace=True)
df.dropna(subset=['A','B','C','G','H','P','U'])
print(df.shape)
# Out:
# (6891, 9)

# %%
# Convert to datetime

df['A'] = df['A'].astype(np.float64)
df['B'] = df['B'].astype(np.float64)
df['C'] = df['C'].astype(np.float64)
df['G'] = df['G'].astype(np.float64)
df['H'] = df['H'].astype(np.float64)
df['P'] = df['P'].astype(np.float64)
df['U'] = df['U'].astype(np.float64)
df['DateTime'] =  pd.to_datetime(df['DateTime'])
df.dtypes
# Out:
# DateTime      datetime64[ns]
# IsoWeekday             int64
# A                    float64
# B                    float64
# C                    float64
# G                    float64
# H                    float64
# P                    float64
# U                    float64
# dtype: object

# %%
# Extract Hour and Minute
df['Hour'] = df.DateTime.apply(lambda x: x.hour)
df['Minute'] = df.DateTime.apply(lambda x: x.minute)
df.head()
# Out:
#                     DateTime  IsoWeekday      A       B      C       G  \
# 0 2018-09-20 01:32:30.850890           4  770.0  2592.0  875.0  1410.0
# 1 2018-09-20 01:39:01.932373           4  773.0  2590.0  876.0  1415.0
# 2 2018-09-20 01:39:40.024931           4  773.0  2591.0  876.0  1414.0
# 3 2018-09-20 01:39:52.258908           4  773.0  2591.0  876.0  1415.0
# 4 2018-09-20 01:40:49.225890           4  773.0  2590.0  876.0  1412.0
#
#         H      P      U  Hour  Minute
# 0  1455.0  310.0  811.0     1      32
# 1  1459.0  310.0  810.0     1      39
# 2  1459.0  310.0  810.0     1      39
# 3  1459.0  310.0  810.0     1      39
# 4  1458.0  310.0  810.0     1      40

# %% [markdown]
# ## Classify the carpark vacant status

# %%
df.describe()
# Out:
#         IsoWeekday            A            B            C            G  \
# count  6891.000000  6857.000000  6856.000000  6857.000000  6853.000000
# mean      4.010013   697.385883  1440.016044   723.302610   772.057931
# std       1.974669   604.831289  1074.659781   667.102289   569.929676
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000    63.000000   292.000000    54.000000   183.000000
# 50%       4.000000   739.000000  1592.500000   726.000000   826.000000
# 75%       6.000000  1057.000000  2575.000000  1071.000000  1372.000000
# max       7.000000  1786.000000  2646.000000  1921.000000  1495.000000
#
#                  H            P            U         Hour       Minute
# count  6851.000000  6855.000000  6855.000000  6891.000000  6891.000000
# mean    779.246679   209.576222   494.911451    11.484400    22.521840
# std     588.127668   106.128075   287.413354     6.928633    16.762178
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     166.000000   121.000000   233.000000     5.000000    15.000000
# 50%     823.000000   254.000000   553.000000    11.000000    30.000000
# 75%    1399.000000   305.000000   779.000000    17.000000    39.500000
# max    1519.000000   317.000000   831.000000    23.000000    46.000000

# %%
# Define status for Carpark Zone A
def A_state(x):
    if x > 1057:
        return 4 # you are early!
    elif x > 739:
        return 3 # plenty of vacancy
    elif x > 63:
        return 2 # limited bay
    elif x > 0:
        return 1 # good luck
    else:
        return 0
    
df['A_State'] = df['A'].apply(A_state)
df.head()
# Out:
#                     DateTime  IsoWeekday      A       B      C       G  \
# 0 2018-09-20 01:32:30.850890           4  770.0  2592.0  875.0  1410.0
# 1 2018-09-20 01:39:01.932373           4  773.0  2590.0  876.0  1415.0
# 2 2018-09-20 01:39:40.024931           4  773.0  2591.0  876.0  1414.0
# 3 2018-09-20 01:39:52.258908           4  773.0  2591.0  876.0  1415.0
# 4 2018-09-20 01:40:49.225890           4  773.0  2590.0  876.0  1412.0
#
#         H      P      U  Hour  Minute  A_State
# 0  1455.0  310.0  811.0     1      32        3
# 1  1459.0  310.0  810.0     1      39        3
# 2  1459.0  310.0  810.0     1      39        3
# 3  1459.0  310.0  810.0     1      39        3
# 4  1458.0  310.0  810.0     1      40        3

# %% [markdown]
# ## Split into dataset of: Train, Validation, Test (70%-20%-10%)

# %%
df_train0, df_valid0, df_test0 = np.split(df.sample(frac=1), [int(.7*len(df)), int(.9*len(df))])

# select only Featured columns
df_train = df_train0[['A_State','Hour','Minute','IsoWeekday']]
df_valid = df_valid0[['A_State','Hour','Minute','IsoWeekday']]
df_test = df_test0[['A_State','Hour','Minute','IsoWeekday']]

print('Train set: {}'.format(df_train.shape))
print('Validate set: {}'.format(df_valid.shape))
print('Test set: {}'.format(df_test.shape))
# Out:
# Train set: (4823, 4)
# Validate set: (1378, 4)
# Test set: (690, 4)

# %% [markdown]
# ## Feature & Label

# %%
FEATURES_NUM = ['Hour','Minute','IsoWeekday']
LABEL = 'A_State'

# %% [markdown]
# ## Determine metrics for validation - Accuracy

# %%
def print_accuracy(model, df):
  metrics = model.evaluate(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    shuffle = False
  ))
  print('Accuracy on dataset = {}'.format(metrics['accuracy']))
    
#print_accuracy(model, df_valid)

# %% [markdown]
# ## Model: DNN Classifier

# %%
# DNNClassifier
OUTDIR = 'model/lab3_class_carpark'
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

model = tf.estimator.DNNClassifier(
    hidden_units = [512, 256, 128], 
    feature_columns = [tf.feature_column.numeric_column('Hour'),
                       tf.feature_column.numeric_column('Minute'),
                       tf.feature_column.numeric_column('IsoWeekday')
                      ], 
    activation_fn = tf.nn.relu,
    n_classes=5,
    optimizer=tf.train.AdamOptimizer(
      learning_rate=0.01,
      #l1_regularization_strength=0.001
    ),
    #loss_reduction='weighted_sum',
    model_dir = OUTDIR,
#    config=tf.estimator.RunConfig(save_summary_steps=2,
#                                  save_checkpoints_steps=2)
)

model.train(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df_train,
    y = df_train[LABEL],
    batch_size = 128,
    num_epochs = 50,
    shuffle = True
  ));

print_accuracy(model, df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'model/lab3_class_carpark', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x129097f60>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into model/lab3_class_carpark/model.ckpt.
# INFO:tensorflow:loss = 258.29306, step = 1
# INFO:tensorflow:global_step/sec: 149.824
# INFO:tensorflow:loss = 137.89597, step = 101 (0.669 sec)
# INFO:tensorflow:global_step/sec: 166.228
# INFO:tensorflow:loss = 126.14005, step = 201 (0.602 sec)
# INFO:tensorflow:global_step/sec: 161.011
# INFO:tensorflow:loss = 94.65638, step = 301 (0.622 sec)
# INFO:tensorflow:global_step/sec: 162.241
# INFO:tensorflow:loss = 92.854996, step = 401 (0.615 sec)
# INFO:tensorflow:global_step/sec: 175.577
# INFO:tensorflow:loss = 76.38631, step = 501 (0.570 sec)
# INFO:tensorflow:global_step/sec: 174.738
# INFO:tensorflow:loss = 71.72798, step = 601 (0.572 sec)
# INFO:tensorflow:global_step/sec: 173.95
# INFO:tensorflow:loss = 65.86628, step = 701 (0.575 sec)
# INFO:tensorflow:global_step/sec: 181.886
# INFO:tensorflow:loss = 92.764175, step = 801 (0.550 sec)
# INFO:tensorflow:global_step/sec: 185.912
# INFO:tensorflow:loss = 79.89484, step = 901 (0.538 sec)
# INFO:tensorflow:global_step/sec: 167.043
# INFO:tensorflow:loss = 72.25086, step = 1001 (0.599 sec)
# INFO:tensorflow:global_step/sec: 156.819
# INFO:tensorflow:loss = 77.23467, step = 1101 (0.637 sec)
# INFO:tensorflow:global_step/sec: 162.886
# INFO:tensorflow:loss = 88.73955, step = 1201 (0.616 sec)
# INFO:tensorflow:global_step/sec: 170.719
# INFO:tensorflow:loss = 70.41685, step = 1301 (0.583 sec)
# INFO:tensorflow:global_step/sec: 187.891
# INFO:tensorflow:loss = 84.08612, step = 1401 (0.532 sec)
# INFO:tensorflow:global_step/sec: 168.517
# INFO:tensorflow:loss = 78.04013, step = 1501 (0.593 sec)
# INFO:tensorflow:global_step/sec: 158.37
# INFO:tensorflow:loss = 78.587296, step = 1601 (0.634 sec)
# INFO:tensorflow:global_step/sec: 166.817
# INFO:tensorflow:loss = 84.99502, step = 1701 (0.597 sec)
# INFO:tensorflow:global_step/sec: 149.911
# INFO:tensorflow:loss = 80.38698, step = 1801 (0.667 sec)
# INFO:tensorflow:Saving checkpoints for 1884 into model/lab3_class_carpark/model.ckpt.
# INFO:tensorflow:Loss for final step: 59.60492.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-14:39:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model/lab3_class_carpark/model.ckpt-1884
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-14:39:44
# INFO:tensorflow:Saving dict for global step 1884: accuracy = 0.7597968, average_loss = 0.58876574, global_step = 1884, loss = 73.75629
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1884: model/lab3_class_carpark/model.ckpt-1884
# Accuracy on dataset = 0.7597967982292175

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(input_fn = tf.estimator.inputs.pandas_input_fn(
#    x = pd.DataFrame({
#                      'Hour':[9,10,12],
#                      'Minute':[0,0,0],
#                      'IsoWeekday':[4,4,5]}),
    x = df_test,
    y = None,
    batch_size = 64,
    shuffle = False
  ))

for items in predictions:
  print(items)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model/lab3_class_carpark/model.ckpt-1884
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([-1.2516205, -2.161142 ,  2.0486822, -0.8526667,  1.0988829],
#       dtype=float32), 'probabilities': array([0.0246885 , 0.00994247, 0.6695732 , 0.03679241, 0.2590034 ],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -3.267331 , -10.292105 ,  -2.482467 ,   1.0915042,   3.195289 ],
#       dtype=float32), 'probabilities': array([1.3848564e-03, 1.2319252e-06, 3.0357558e-03, 1.0824874e-01,
#        8.8732940e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([  0.48752907, -11.403676  ,  -1.1975534 ,   2.896935  ,
#          5.3631115 ], dtype=float32), 'probabilities': array([6.9752904e-03, 4.7783395e-08, 1.2934214e-03, 7.7616468e-02,
#        9.1411477e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.657442  , -8.85248   , -0.21288842,  3.0770617 ,  0.8969183 ],
#       dtype=float32), 'probabilities': array([2.8022798e-03, 5.7153229e-06, 3.2297406e-02, 8.6691165e-01,
#        9.7982965e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.9037845, -2.8781784,  2.3984694,  2.225658 , -0.7935098],
#       dtype=float32), 'probabilities': array([0.00096975, 0.00270442, 0.5292886 , 0.44528848, 0.02174871],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.542749  , -4.1959453 ,  2.3643744 ,  0.47635406,  1.7382853 ],
#       dtype=float32), 'probabilities': array([0.00160929, 0.00083744, 0.5916511 , 0.08955892, 0.3163433 ],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.598122  , -5.0765905 ,  2.8672225 , -0.38267022, -0.39746773],
#       dtype=float32), 'probabilities': array([5.3119962e-04, 3.2920114e-04, 9.2771727e-01, 3.5975363e-02,
#        3.5446931e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.2277055,  4.0309634, -0.349064 , -6.194789 ,  1.355717 ],
#       dtype=float32), 'probabilities': array([5.2957499e-01, 4.3499422e-01, 5.4483102e-03, 1.5757796e-05,
#        2.9966684e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 3.8566105e+00,  3.8386528e+00,  4.1322708e-03, -6.2482157e+00,
#         8.9399767e-01], dtype=float32), 'probabilities': array([4.8658153e-01, 4.7792163e-01, 1.0328698e-02, 1.9892321e-05,
#        2.5148332e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-3.2651987, -1.1326821,  2.8473914,  1.0748577, -1.7831734],
#       dtype=float32), 'probabilities': array([0.00184483, 0.01556308, 0.83295137, 0.14152008, 0.00812065],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-0.53511703,  1.8601036 ,  3.40233   , -2.3871512 , -4.12181   ],
#       dtype=float32), 'probabilities': array([1.5762247e-02, 1.7292163e-01, 8.0840629e-01, 2.4733751e-03,
#        4.3645274e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([  2.9234936, -13.73062  ,  -7.555685 ,  -4.0816774,  10.817715 ],
#       dtype=float32), 'probabilities': array([3.7275301e-04, 2.1808763e-11, 1.0480254e-08, 3.3815368e-07,
#        9.9962687e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.9299109,  1.8961939,  3.178458 , -1.6873484, -4.328492 ],
#       dtype=float32), 'probabilities': array([4.6805711e-03, 2.1476081e-01, 7.7416807e-01, 5.9654377e-03,
#        4.2521456e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.0252855, -2.1446836,  2.759884 , -0.4471063, -0.7171039],
#       dtype=float32), 'probabilities': array([0.00768317, 0.00681846, 0.9198414 , 0.03723357, 0.02842341],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.1850512, -9.592915 , -0.5279222,  3.35209  ,  2.0337403],
#       dtype=float32), 'probabilities': array([3.0474148e-03, 1.8481501e-06, 1.5981348e-02, 7.7389359e-01,
#        2.0707577e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.6719071,  3.4488833,  2.479543 , -4.59592  , -3.447639 ],
#       dtype=float32), 'probabilities': array([1.0914138e-01, 6.4523870e-01, 2.4476045e-01, 2.0696961e-04,
#        6.5252738e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-0.67943037,  3.327094  ,  3.6359963 , -3.4541044 , -5.3863773 ],
#       dtype=float32), 'probabilities': array([7.6410235e-03, 4.1991660e-01, 5.7189673e-01, 4.7656920e-04,
#        6.9016147e-05], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.010742  , -9.797453  , -0.06601948,  3.1368933 ,  0.45444345],
#       dtype=float32), 'probabilities': array([7.0886844e-04, 2.1748490e-06, 3.6621567e-02, 9.0104043e-01,
#        6.1627012e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.1630857 , -5.5332456 , -0.32446724, -0.07748586,  2.4105794 ],
#       dtype=float32), 'probabilities': array([2.3846976e-02, 3.0164566e-04, 5.5162087e-02, 7.0616037e-02,
#        8.5007328e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.657442  , -8.85248   , -0.21288842,  3.0770617 ,  0.8969183 ],
#       dtype=float32), 'probabilities': array([2.8022798e-03, 5.7153229e-06, 3.2297406e-02, 8.6691165e-01,
#        9.7982965e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 5.541238  ,  5.7965913 ,  0.8334299 , -6.6695404 , -0.88900304],
#       dtype=float32), 'probabilities': array([4.3448803e-01, 5.6088835e-01, 3.9210538e-03, 2.1622425e-06,
#        7.0042169e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 1.1683776,  2.5954509,  1.7467363, -3.9745584, -1.3401878],
#       dtype=float32), 'probabilities': array([0.1421096 , 0.5920978 , 0.25339696, 0.00082999, 0.01156558],
#       dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-5.7304816, -8.581491 ,  2.2525587,  1.6876342,  2.6955576],
#       dtype=float32), 'probabilities': array([1.0914459e-04, 6.3070192e-06, 3.1988388e-01, 1.8182299e-01,
#        4.9817777e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 5.536958  ,  4.3849387 , -0.60457176, -6.903366  ,  1.7769563 ],
#       dtype=float32), 'probabilities': array([7.4546909e-01, 2.3556671e-01, 1.6039729e-03, 2.9489354e-06,
#        1.7357277e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 3.6018798,  4.355661 ,  2.3950481, -5.8949156, -3.9289417],
#       dtype=float32), 'probabilities': array([2.9199001e-01, 6.2048453e-01, 8.7346934e-02, 2.1926149e-05,
#        1.5659344e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([  5.6481795, -17.794939 , -10.540158 ,  -5.9973774,  14.696518 ],
#       dtype=float32), 'probabilities': array([1.17572483e-04, 7.74621032e-15, 1.09597375e-11, 1.02968500e-09,
#        9.99882460e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.5235934 , -5.7680445 , -0.42170262,  0.32653075,  2.6602318 ],
#       dtype=float32), 'probabilities': array([1.3157687e-02, 1.8872877e-04, 3.9602697e-02, 8.3690926e-02,
#        8.6335993e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 5.132506 ,  5.7828236,  1.1784286, -6.6000347, -1.4008448],
#       dtype=float32), 'probabilities': array([3.4050810e-01, 6.5246439e-01, 6.5297042e-03, 2.7336932e-06,
#        4.9514155e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.9096925 , -4.011232  ,  2.4944623 ,  0.08393613,  1.1205657 ],
#       dtype=float32), 'probabilities': array([0.00333451, 0.00110825, 0.741356  , 0.06655009, 0.18765108],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -4.9365277 , -10.275941  ,  -0.21500468,   3.1329288 ,
#          0.5450288 ], dtype=float32), 'probabilities': array([2.8177522e-04, 1.3521502e-06, 3.1654395e-02, 9.0037429e-01,
#        6.7688100e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.2503068,  5.301106 ,  3.5983176, -6.692102 , -6.353179 ],
#       dtype=float32), 'probabilities': array([9.8130859e-02, 7.6288021e-01, 1.3897759e-01, 4.7192430e-06,
#        6.6231482e-06], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-7.3563094, -7.180474 ,  2.5637357,  0.9476979,  0.6072614],
#       dtype=float32), 'probabilities': array([3.6696656e-05, 4.3751294e-05, 7.4618626e-01, 1.4825554e-01,
#        1.0547784e-01], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.86381805,  4.2381053 ,  3.7249446 , -4.9086313 , -5.762372  ],
#       dtype=float32), 'probabilities': array([2.0969151e-02, 6.1237174e-01, 3.6656606e-01, 6.5258653e-05,
#        2.7788379e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.8537295 ,  0.21932544,  2.9089844 , -0.4792313 , -2.4212322 ],
#       dtype=float32), 'probabilities': array([0.00766094, 0.06089735, 0.896814  , 0.0302844 , 0.00434329],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.1261945, -6.9013314,  2.5473547,  5.1642346, -1.0828824],
#       dtype=float32), 'probabilities': array([8.5858512e-05, 5.3525005e-06, 6.7931145e-02, 9.3017673e-01,
#        1.8008478e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 5.2125354,  4.0715775,  1.0866253, -6.255816 , -1.8166001],
#       dtype=float32), 'probabilities': array([7.4819058e-01, 2.3905650e-01, 1.2082377e-02, 7.8229496e-06,
#        6.6267012e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-17.679039 , -13.297424 ,   4.4814377,   2.8473601,  11.186332 ],
#       dtype=float32), 'probabilities': array([2.9059827e-13, 2.3238290e-11, 1.2231120e-03, 2.3866852e-04,
#        9.9853826e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -3.7372863 , -10.164562  ,  -0.29573137,   3.23069   ,
#          0.5696027 ], dtype=float32), 'probabilities': array([8.5578486e-04, 1.3836755e-06, 2.6730867e-02, 9.0890473e-01,
#        6.3507177e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.2710083 ,  2.3235657 ,  1.1641603 , -4.1958585 , -0.54118717],
#       dtype=float32), 'probabilities': array([6.5273160e-01, 2.5308451e-01, 7.9385683e-02, 3.7317775e-04,
#        1.4425114e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-19.14043  ,  -9.373177 ,   4.051647 ,   0.7180188,   8.313761 ],
#       dtype=float32), 'probabilities': array([1.1762604e-12, 2.0529004e-08, 1.3889762e-02, 4.9535697e-04,
#        9.8561478e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([  6.0583863, -18.57157  , -11.198004 ,  -6.533806 ,  15.656945 ],
#       dtype=float32), 'probabilities': array([6.7821842e-05, 1.3636881e-15, 2.1727711e-12, 2.3048900e-10,
#        9.9993217e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.0468822,  2.7128546,  1.7725031, -3.8015747, -1.6109887],
#       dtype=float32), 'probabilities': array([0.4984582 , 0.35691306, 0.13937119, 0.00052891, 0.00472869],
#       dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-1.5752869 ,  0.55237794,  3.2406514 , -0.22261441, -2.8223314 ],
#       dtype=float32), 'probabilities': array([0.00729858, 0.06127334, 0.90110177, 0.02822907, 0.00209727],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.218261 ,  2.1324048,  1.7418208, -3.4654074, -2.0760713],
#       dtype=float32), 'probabilities': array([0.6359975 , 0.21472076, 0.1452933 , 0.00079575, 0.00319268],
#       dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-6.577795  , -6.993345  ,  2.6005955 ,  0.4575953 ,  0.41610742],
#       dtype=float32), 'probabilities': array([8.3939674e-05, 5.5398261e-05, 8.1300205e-01, 9.5367089e-02,
#        9.1491453e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 5.3681107,  4.3774085, -0.629605 , -6.475482 ,  1.6832991],
#       dtype=float32), 'probabilities': array([7.1484256e-01, 2.6543242e-01, 1.7759702e-03, 5.1357451e-06,
#        1.7943909e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -1.480991  , -10.551214  ,  -0.67800957,   3.4435432 ,
#          1.148169  ], dtype=float32), 'probabilities': array([6.4633028e-03, 7.4354375e-07, 1.4427293e-02, 8.8951355e-01,
#        8.9595094e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -1.6508381, -11.195953 ,  -1.1624038,   3.7481008,   2.498976 ],
#       dtype=float32), 'probabilities': array([3.4816067e-03, 2.4910884e-07, 5.6741945e-03, 7.7003270e-01,
#        2.2081125e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.8406112 , -3.1737726 ,  0.70561385, -0.18722051,  0.40682447],
#       dtype=float32), 'probabilities': array([0.03483035, 0.00918276, 0.44439515, 0.1819769 , 0.32961482],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -3.847597 , -10.261532 ,  -2.8852508,  -0.4891284,   5.3266   ],
#       dtype=float32), 'probabilities': array([1.0333368e-04, 1.6931889e-07, 2.7051009e-04, 2.9703404e-03,
#        9.9665558e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.8449569, -4.7461247,  2.2939065,  3.0155833, -0.4458611],
#       dtype=float32), 'probabilities': array([5.0778971e-03, 2.7907614e-04, 3.1854403e-01, 6.5552574e-01,
#        2.0573281e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 5.399269  ,  5.138085  , -0.17589968, -6.6917586 ,  1.103399  ],
#       dtype=float32), 'probabilities': array([5.5942178e-01, 4.3083256e-01, 2.1206765e-03, 3.1381417e-06,
#        7.6219626e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 2.9753087,  4.220548 ,  1.3039966, -3.5347652, -0.5472417],
#       dtype=float32), 'probabilities': array([2.1309336e-01, 7.4023658e-01, 4.0061597e-02, 3.1716170e-04,
#        6.2913769e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.5244772 , -5.7664247 , -0.4874255 ,  0.31632668,  2.6984134 ],
#       dtype=float32), 'probabilities': array([1.2760422e-02, 1.8348932e-04, 3.5995729e-02, 8.0411121e-02,
#        8.7064928e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.7846005 , -1.0847331 ,  1.636066  , -0.03076023, -1.3278689 ],
#       dtype=float32), 'probabilities': array([0.00912245, 0.04992921, 0.7585473 , 0.14324822, 0.03915273],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -5.37597   , -10.397709  ,   0.1352432 ,   3.4860072 ,
#          0.63184786], dtype=float32), 'probabilities': array([1.2964330e-04, 8.5474409e-07, 3.2080363e-02, 9.1507691e-01,
#        5.2712295e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -2.533113 , -12.270692 ,  -0.3430935,   5.006487 ,   1.368252 ],
#       dtype=float32), 'probabilities': array([5.1533571e-04, 3.0416764e-08, 4.6047242e-03, 9.6938622e-01,
#        2.5493620e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -3.1993492 , -11.963045  ,   1.1581612 ,   5.259517  ,
#          0.28931475], dtype=float32), 'probabilities': array([2.0710315e-04, 3.2371410e-08, 1.6166994e-02, 9.7684485e-01,
#        6.7810058e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.5957007,  3.587806 , -0.0127477, -5.794919 ,  1.1972115],
#       dtype=float32), 'probabilities': array([7.1002132e-01, 2.5914821e-01, 7.0769745e-03, 2.1811360e-05,
#        2.3731558e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 4.2823396,  4.4916196,  1.3225269, -6.739348 , -1.955909 ],
#       dtype=float32), 'probabilities': array([4.3733275e-01, 5.3913951e-01, 2.2666356e-02, 7.1474960e-06,
#        8.5423031e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([  2.58128  , -13.666466 ,  -1.5618823,   3.8839455,   6.611825 ],
#       dtype=float32), 'probabilities': array([1.6397055e-02, 1.4403235e-09, 2.6026368e-04, 6.0326260e-02,
#        9.2301643e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 6.020764  ,  5.8921075 ,  0.7477724 , -6.6902213 , -0.95790315],
#       dtype=float32), 'probabilities': array([5.3040862e-01, 4.6637559e-01, 2.7200659e-03, 1.6006628e-06,
#        4.9409893e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 0.3851352,  2.4315321,  2.7034206, -2.4596088, -2.4758105],
#       dtype=float32), 'probabilities': array([0.05259402, 0.40707576, 0.5342628 , 0.0030583 , 0.00300915],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -1.480991  , -10.551214  ,  -0.67800957,   3.4435432 ,
#          1.148169  ], dtype=float32), 'probabilities': array([6.4633028e-03, 7.4354375e-07, 1.4427293e-02, 8.8951355e-01,
#        8.9595094e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.790491  ,  5.0454783 ,  0.50179404, -6.450806  , -0.25149298],
#       dtype=float32), 'probabilities': array([4.3278012e-01, 5.5847901e-01, 5.9389514e-03, 5.6785043e-06,
#        2.7961563e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-17.736683 , -13.351828 ,   4.55722  ,   2.4031284,  11.85646  ],
#       dtype=float32), 'probabilities': array([1.4045382e-13, 1.1268156e-11, 6.7554298e-04, 7.8368757e-05,
#        9.9924612e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.5997863 , -3.95972   ,  1.1292201 ,  0.6525303 ,  0.18216467],
#       dtype=float32), 'probabilities': array([0.00436585, 0.00304615, 0.49414042, 0.3067797 , 0.1916679 ],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-0.8142407 , -1.1453385 ,  2.1104014 , -0.85017186,  0.8367728 ],
#       dtype=float32), 'probabilities': array([0.03770361, 0.02707628, 0.7023262 , 0.03637293, 0.19652101],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.022537 ,  4.669506 ,  3.05614  , -6.633139 , -5.7290735],
#       dtype=float32), 'probabilities': array([3.0392581e-01, 5.8042032e-01, 1.1562896e-01, 7.1625286e-06,
#        1.7688739e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -0.47631428, -10.181679  ,  -0.9210587 ,   2.6468065 ,
#          4.941991  ], dtype=float32), 'probabilities': array([4.0023248e-03, 2.4396414e-07, 2.5654421e-03, 9.0921454e-02,
#        9.0251052e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -5.7706037 , -10.249991  ,   0.21377927,   3.4356432 ,
#          0.68434596], dtype=float32), 'probabilities': array([9.0965448e-05, 1.0315810e-06, 3.6129434e-02, 9.0593886e-01,
#        5.7839654e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.7978029 ,  0.03181063,  3.3477006 ,  0.2747714 , -2.5377295 ],
#       dtype=float32), 'probabilities': array([0.00533869, 0.03326795, 0.9164288 , 0.04241725, 0.00254735],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.6813984,  4.4639425,  2.9613981, -5.964963 , -5.4370127],
#       dtype=float32), 'probabilities': array([2.7218619e-01, 5.9527916e-01, 1.3248721e-01, 1.7599672e-05,
#        2.9839426e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.6140945 , -7.432529  ,  0.14151675,  2.3999462 ,  2.9365208 ],
#       dtype=float32), 'probabilities': array([6.3754870e-03, 1.8949566e-05, 3.6894836e-02, 3.5301167e-01,
#        6.0369903e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-6.1656337 , -9.312315  ,  0.20150614,  3.0388536 ,  0.5572381 ],
#       dtype=float32), 'probabilities': array([8.8057095e-05, 3.7859757e-06, 5.1283520e-02, 8.7543154e-01,
#        7.3193118e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -3.743194  , -10.819404  ,  -3.4681814 ,  -0.97314674,
#          6.198557  ], dtype=float32), 'probabilities': array([4.8080656e-05, 4.0626766e-08, 6.3300482e-05, 7.6733815e-04,
#        9.9912125e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.34112749,  2.3717654 ,  3.5323129 , -1.3972943 , -3.3283195 ],
#       dtype=float32), 'probabilities': array([0.03017732, 0.22991933, 0.733829  , 0.0053051 , 0.00076924],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 5.506104  ,  5.6388307 ,  0.4667769 , -6.258953  , -0.07974434],
#       dtype=float32), 'probabilities': array([4.6464637e-01, 5.3059727e-01, 3.0100283e-03, 3.6109661e-06,
#        1.7426872e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-4.565489 , -7.101524 ,  1.9283803,  1.707166 ,  1.7678559],
#       dtype=float32), 'probabilities': array([5.6977663e-04, 4.5114732e-05, 3.7666565e-01, 3.0191442e-01,
#        3.2080504e-01], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.1316226,  0.5567995,  2.5037048, -1.032345 , -3.0132864],
#       dtype=float32), 'probabilities': array([0.00818423, 0.12037732, 0.8434803 , 0.02456903, 0.00338904],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.9344559,  4.6678576,  3.944826 , -5.391132 , -6.208247 ],
#       dtype=float32), 'probabilities': array([1.5843187e-02, 6.6257995e-01, 3.2153600e-01, 2.8357939e-05,
#        1.2525820e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -2.5597699 , -10.123156  ,  -0.30484718,   3.5179715 ,
#          1.1736417 ], dtype=float32), 'probabilities': array([2.0475022e-03, 1.0628892e-06, 1.9522028e-02, 8.9279968e-01,
#        8.5629717e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.1261945, -6.9013314,  2.5473547,  5.1642346, -1.0828824],
#       dtype=float32), 'probabilities': array([8.5858512e-05, 5.3525005e-06, 6.7931145e-02, 9.3017673e-01,
#        1.8008478e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -3.4223535, -11.44587  ,   1.371964 ,   6.22614  ,  -0.7569233],
#       dtype=float32), 'probabilities': array([6.3960615e-05, 2.0957698e-08, 7.7278432e-03, 9.9128878e-01,
#        9.1937854e-04], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.5805464,  3.3203604,  1.2120447, -5.4249883, -1.5913043],
#       dtype=float32), 'probabilities': array([7.5747532e-01, 2.1482097e-01, 2.6088361e-02, 3.4199504e-05,
#        1.5811308e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -5.37597   , -10.397709  ,   0.1352432 ,   3.4860072 ,
#          0.63184786], dtype=float32), 'probabilities': array([1.2964330e-04, 8.5474409e-07, 3.2080363e-02, 9.1507691e-01,
#        5.2712295e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.8171554 ,  4.2400002 , -0.55968446, -6.396016  ,  1.7023525 ],
#       dtype=float32), 'probabilities': array([6.2091881e-01, 3.4864184e-01, 2.8701397e-03, 8.3794694e-06,
#        2.7560884e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -3.4223535, -11.44587  ,   1.371964 ,   6.22614  ,  -0.7569233],
#       dtype=float32), 'probabilities': array([6.3960615e-05, 2.0957698e-08, 7.7278432e-03, 9.9128878e-01,
#        9.1937854e-04], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-5.6910443, -7.155538 ,  0.7664268,  3.1271267,  0.5572473],
#       dtype=float32), 'probabilities': array([1.2639508e-04, 2.9221885e-05, 8.0570124e-02, 8.5391176e-01,
#        6.5362468e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.8143666,  4.9117804,  2.6336844, -6.317187 , -4.4661865],
#       dtype=float32), 'probabilities': array([1.0019463e-01, 8.1609309e-01, 8.3632521e-02, 1.0840792e-05,
#        6.9014517e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.0252855, -2.1446836,  2.759884 , -0.4471063, -0.7171039],
#       dtype=float32), 'probabilities': array([0.00768317, 0.00681846, 0.9198414 , 0.03723357, 0.02842341],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.4796975 , -0.9001496 ,  1.7262993 , -0.32225263, -1.5204039 ],
#       dtype=float32), 'probabilities': array([0.01187662, 0.05763439, 0.7967718 , 0.10272098, 0.03099622],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-5.913789  , -9.993248  ,  0.18509242,  3.273888  ,  0.6152699 ],
#       dtype=float32), 'probabilities': array([9.1683818e-05, 1.5509810e-06, 4.0832255e-02, 8.9629358e-01,
#        6.2780835e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.5957007,  3.587806 , -0.0127477, -5.794919 ,  1.1972115],
#       dtype=float32), 'probabilities': array([7.1002132e-01, 2.5914821e-01, 7.0769745e-03, 2.1811360e-05,
#        2.3731558e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-6.0553784, -7.89189  ,  3.6382546,  6.4436016, -1.8278992],
#       dtype=float32), 'probabilities': array([3.5168255e-06, 5.6048498e-07, 5.7021938e-02, 9.4273293e-01,
#        2.4105805e-04], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -1.3630395, -11.45337  ,  -1.0343318,   3.79378  ,   2.055375 ],
#       dtype=float32), 'probabilities': array([4.8421095e-03, 2.0084428e-07, 6.7265215e-03, 8.4064525e-01,
#        1.4778593e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.7394801 ,  0.48061776,  3.0504622 , -0.88370043, -2.621395  ],
#       dtype=float32), 'probabilities': array([0.00750357, 0.06909464, 0.90263796, 0.01765747, 0.0031064 ],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 5.7495937 ,  5.2585807 ,  0.1122883 , -6.5835657 ,  0.17194319],
#       dtype=float32), 'probabilities': array([6.1753005e-01, 3.7793213e-01, 2.1999232e-03, 2.7191616e-06,
#        2.3351526e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-0.72944665, -9.138631  ,  0.1440289 ,  3.028472  ,  3.3082612 ],
#       dtype=float32), 'probabilities': array([9.7133778e-03, 2.1642531e-06, 2.3265688e-02, 4.1630685e-01,
#        5.5071193e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 5.536958  ,  4.3849387 , -0.60457176, -6.903366  ,  1.7769563 ],
#       dtype=float32), 'probabilities': array([7.4546909e-01, 2.3556671e-01, 1.6039729e-03, 2.9489354e-06,
#        1.7357277e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -3.4521325 , -12.231176  ,   0.23816562,   4.8454847 ,
#          0.90699875], dtype=float32), 'probabilities': array([2.4192332e-04, 3.7238117e-08, 9.6906712e-03, 9.7115153e-01,
#        1.8915780e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.2819595, -5.5858693,  1.581815 ,  2.6958866,  1.1041853],
#       dtype=float32), 'probabilities': array([1.6514413e-03, 1.6492559e-04, 2.1388167e-01, 6.5164149e-01,
#        1.3266051e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 0.8938228,  4.5770874,  3.8789918, -5.2515774, -6.135315 ],
#       dtype=float32), 'probabilities': array([1.6510118e-02, 6.5670711e-01, 3.2673275e-01, 3.5386438e-05,
#        1.4622932e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-4.1572714 , -8.314254  ,  0.7496754 ,  2.2167666 , -0.22601771],
#       dtype=float32), 'probabilities': array([1.2926022e-03, 2.0235333e-05, 1.7479326e-01, 7.5800890e-01,
#        6.5885000e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.9570374, -5.468555 ,  1.4081705,  2.5421023,  1.1040537],
#       dtype=float32), 'probabilities': array([2.6159794e-03, 2.1227365e-04, 2.0578799e-01, 6.3955861e-01,
#        1.5182517e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.923642 , -3.1147847,  2.4192924,  2.3243842, -0.648105 ],
#       dtype=float32), 'probabilities': array([0.00089674, 0.00201348, 0.50976   , 0.4636045 , 0.02372531],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.2099135 , -3.3196008 ,  0.59993756,  0.16304094,  0.6071441 ],
#       dtype=float32), 'probabilities': array([0.02202948, 0.00726228, 0.36585343, 0.2363553 , 0.3684995 ],
#       dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.40361628,  2.1672072 ,  2.6821523 , -2.214762  , -2.1241174 ],
#       dtype=float32), 'probabilities': array([0.05970689, 0.34829104, 0.5828812 , 0.00435389, 0.00476698],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.7899356, -8.506084 ,  1.2874358,  3.5262613,  1.4288166],
#       dtype=float32), 'probabilities': array([5.4038398e-04, 4.8362090e-06, 8.6651653e-02, 8.1299227e-01,
#        9.9810846e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([  2.9234936, -13.73062  ,  -7.555685 ,  -4.0816774,  10.817715 ],
#       dtype=float32), 'probabilities': array([3.7275301e-04, 2.1808763e-11, 1.0480254e-08, 3.3815368e-07,
#        9.9962687e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.2349253, -7.871445 , -2.2574818, -0.9706945,  4.88795  ],
#       dtype=float32), 'probabilities': array([2.9550924e-04, 2.8638867e-06, 7.8536116e-04, 2.8438976e-03,
#        9.9607241e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-19.14043  ,  -9.373177 ,   4.051647 ,   0.7180188,   8.313761 ],
#       dtype=float32), 'probabilities': array([1.1762604e-12, 2.0529004e-08, 1.3889762e-02, 4.9535697e-04,
#        9.8561478e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -3.267331 , -10.292105 ,  -2.482467 ,   1.0915042,   3.195289 ],
#       dtype=float32), 'probabilities': array([1.3848564e-03, 1.2319252e-06, 3.0357558e-03, 1.0824874e-01,
#        8.8732940e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.380726 , -1.1153134,  2.7837894,  1.1531456, -1.6677005],
#       dtype=float32), 'probabilities': array([0.00170978, 0.01647392, 0.81312215, 0.15921213, 0.00948196],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.2641907 , -1.2493049 ,  1.9261222 ,  1.50004   ,  0.36284077],
#       dtype=float32), 'probabilities': array([0.00291659, 0.02187403, 0.52359945, 0.34194326, 0.10966668],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.2780551,  2.9965303,  3.768559 , -2.1075673, -4.065196 ],
#       dtype=float32), 'probabilities': array([2.0381259e-02, 3.0892265e-01, 6.6855562e-01, 1.8757214e-03,
#        2.6483843e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.923899 , -3.9015062,  2.1695628,  2.4104245, -0.574757 ],
#       dtype=float32), 'probabilities': array([0.00261685, 0.00098449, 0.42642426, 0.5425588 , 0.02741568],
#       dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.010742  , -9.797453  , -0.06601948,  3.1368933 ,  0.45444345],
#       dtype=float32), 'probabilities': array([7.0886844e-04, 2.1748490e-06, 3.6621567e-02, 9.0104043e-01,
#        6.1627012e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.606141 ,  1.6099242,  1.7669382, -2.5161703, -2.0088663],
#       dtype=float32), 'probabilities': array([0.5502993 , 0.20321111, 0.23775944, 0.00328101, 0.00544912],
#       dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-3.6815798 , -2.966553  ,  1.974643  ,  1.4991472 , -0.51695585],
#       dtype=float32), 'probabilities': array([0.00203831, 0.0041668 , 0.58309174, 0.3624363 , 0.04826688],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -1.3630395, -11.45337  ,  -1.0343318,   3.79378  ,   2.055375 ],
#       dtype=float32), 'probabilities': array([4.8421095e-03, 2.0084428e-07, 6.7265215e-03, 8.4064525e-01,
#        1.4778593e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.8828914,  0.4168417,  2.431375 , -0.0863263, -2.9072313],
#       dtype=float32), 'probabilities': array([0.00402115, 0.10899495, 0.81715983, 0.06589966, 0.00392446],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.7270434,  5.019903 ,  2.8314312, -6.399279 , -4.787572 ],
#       dtype=float32), 'probabilities': array([8.3236896e-02, 8.2431316e-01, 9.2395514e-02, 9.0532512e-06,
#        4.5369074e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-5.632691 , -7.1830745,  3.5749662,  6.352127 , -1.836751 ],
#       dtype=float32), 'probabilities': array([5.8712540e-06, 1.2456826e-06, 5.8555178e-02, 9.4117624e-01,
#        2.6138846e-04], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.9826071 , -8.80732   ,  0.7997061 ,  4.223631  ,  0.01623237],
#       dtype=float32), 'probabilities': array([1.9217088e-03, 2.0881057e-06, 3.1047788e-02, 9.5284528e-01,
#        1.4183143e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -2.3118875 , -11.672298  ,  -0.59535736,   3.9338002 ,
#          1.4961419 ], dtype=float32), 'probabilities': array([1.7623925e-03, 1.5167987e-07, 9.8080365e-03, 9.0901333e-01,
#        7.9416126e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.161856  ,  0.46863508,  2.4363153 , -0.9095691 , -2.9329457 ],
#       dtype=float32), 'probabilities': array([0.00846425, 0.1174887 , 0.8405214 , 0.02961077, 0.00391479],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.9299109,  1.8961939,  3.178458 , -1.6873484, -4.328492 ],
#       dtype=float32), 'probabilities': array([4.6805711e-03, 2.1476081e-01, 7.7416807e-01, 5.9654377e-03,
#        4.2521456e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([  4.2892714, -17.642733 , -10.306974 ,  -5.956572 ,  14.577353 ],
#       dtype=float32), 'probabilities': array([3.40352017e-05, 1.01620194e-14, 1.55904751e-11, 1.20841259e-09,
#        9.99965906e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.1513762 , -9.531871  , -0.18470436,  3.096285  ,  0.47346032],
#       dtype=float32), 'probabilities': array([1.7398858e-03, 2.9478633e-06, 3.3801042e-02, 8.9917803e-01,
#        6.5278091e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.4803643 , -6.6851997 ,  1.3915987 ,  1.9666717 , -0.58024096],
#       dtype=float32), 'probabilities': array([7.08658388e-03, 1.05754756e-04, 3.40415239e-01, 6.05006456e-01,
#        4.73859832e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -3.867965  , -11.851852  ,   1.1608944 ,   5.6087713 ,
#         -0.28010553], dtype=float32), 'probabilities': array([7.5514843e-05, 2.5743853e-08, 1.1535545e-02, 9.8565859e-01,
#        2.7303589e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -3.4320123 , -10.101724  ,   1.4968061 ,   5.352167  ,
#         -0.61482525], dtype=float32), 'probabilities': array([1.4956489e-04, 1.8976274e-07, 2.0672282e-02, 9.7667581e-01,
#        2.5021802e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-5.4722667 , -7.237625  ,  0.20896405,  0.14845264,  2.5334358 ],
#       dtype=float32), 'probabilities': array([2.8022376e-04, 4.7953439e-05, 8.2192533e-02, 7.7366441e-02,
#        8.4011281e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-4.1280947 , -4.917024  ,  0.31164032,  0.40154535,  1.3158112 ],
#       dtype=float32), 'probabilities': array([0.00243738, 0.00110738, 0.2065743 , 0.22600682, 0.5638741 ],
#       dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.350757  , -9.219654  ,  0.0813123 ,  2.7674367 ,  0.22775805],
#       dtype=float32), 'probabilities': array([1.9164155e-03, 5.4157658e-06, 5.9295055e-02, 8.7013656e-01,
#        6.8646602e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.36066362, -9.739679  , -0.95166725,  2.4369106 ,  4.800791  ],
#       dtype=float32), 'probabilities': array([5.1981388e-03, 4.3912985e-07, 2.8785788e-03, 8.5274428e-02,
#        9.0664846e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -3.847597 , -10.261532 ,  -2.8852508,  -0.4891284,   5.3266   ],
#       dtype=float32), 'probabilities': array([1.0333368e-04, 1.6931889e-07, 2.7051009e-04, 2.9703404e-03,
#        9.9665558e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.6204183 , -5.643914  , -0.45823032,  0.36018807,  2.6193395 ],
#       dtype=float32), 'probabilities': array([1.2368130e-02, 2.2126955e-04, 3.9539922e-02, 8.9633495e-02,
#        8.5823721e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -1.480991  , -10.551214  ,  -0.67800957,   3.4435432 ,
#          1.148169  ], dtype=float32), 'probabilities': array([6.4633028e-03, 7.4354375e-07, 1.4427293e-02, 8.8951355e-01,
#        8.9595094e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 6.0980887,  6.0054464,  1.0050852, -6.679229 , -1.4921737],
#       dtype=float32), 'probabilities': array([5.2133095e-01, 4.7520331e-01, 3.2007392e-03, 1.4722963e-06,
#        2.6345378e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -3.2940228, -11.731625 ,   0.3743267,   4.805674 ,   0.6938069],
#       dtype=float32), 'probabilities': array([2.9519462e-04, 6.3930024e-08, 1.1567846e-02, 9.7221476e-01,
#        1.5922125e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([  2.4067175, -16.514572 ,  -8.971738 ,  -5.0456486,  13.17673  ],
#       dtype=float32), 'probabilities': array([2.1020051e-05, 1.2741534e-13, 2.4045479e-10, 1.2193062e-08,
#        9.9997902e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-0.7432773, -2.627363 ,  2.9127562,  2.1451225, -1.819048 ],
#       dtype=float32), 'probabilities': array([0.01719246, 0.0026127 , 0.6654771 , 0.30885458, 0.00586323],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-0.2649255 , -0.57277423,  2.7195315 , -0.9663177 , -2.349077  ],
#       dtype=float32), 'probabilities': array([0.04518529, 0.03321239, 0.8935735 , 0.02240713, 0.00562162],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([  4.2892714, -17.642733 , -10.306974 ,  -5.956572 ,  14.577353 ],
#       dtype=float32), 'probabilities': array([3.40352017e-05, 1.01620194e-14, 1.55904751e-11, 1.20841259e-09,
#        9.99965906e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -3.847597 , -10.261532 ,  -2.8852508,  -0.4891284,   5.3266   ],
#       dtype=float32), 'probabilities': array([1.0333368e-04, 1.6931889e-07, 2.7051009e-04, 2.9703404e-03,
#        9.9665558e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.901588  ,  3.922468  ,  0.20854479, -6.3343697 ,  0.4891194 ],
#       dtype=float32), 'probabilities': array([4.81002510e-01, 4.91151422e-01, 1.19750975e-02, 1.72475466e-05,
#        1.58537142e-02], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([  6.5850797, -14.820263 , -15.479655 , -13.102018 ,  19.762575 ],
#       dtype=float32), 'probabilities': array([1.8927157e-06, 9.5689132e-16, 4.9487254e-16, 5.3344246e-15,
#        9.9999809e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 5.541238  ,  5.7965913 ,  0.8334299 , -6.6695404 , -0.88900304],
#       dtype=float32), 'probabilities': array([4.3448803e-01, 5.6088835e-01, 3.9210538e-03, 2.1622425e-06,
#        7.0042169e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -0.7210643, -10.3376   ,  -0.8822463,   2.7822757,   5.0879774],
#       dtype=float32), 'probabilities': array([2.7146093e-03, 1.8084197e-07, 2.3105051e-03, 9.0196297e-02,
#        9.0477842e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -0.59844947, -10.345521  ,  -0.9087997 ,   2.7210054 ,
#          5.0481195 ], dtype=float32), 'probabilities': array([3.1979906e-03, 1.8697258e-07, 2.3447357e-03, 8.8409364e-02,
#        9.0604770e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -3.34985   , -11.141438  ,   0.11551595,   4.330816  ,
#          1.1977806 ], dtype=float32), 'probabilities': array([4.3602267e-04, 1.8016294e-07, 1.3947570e-02, 9.4445205e-01,
#        4.1164234e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.4513535 ,  4.176083  ,  0.95195323, -6.198999  , -1.4985704 ],
#       dtype=float32), 'probabilities': array([5.5796969e-01, 4.2370364e-01, 1.6859330e-02, 1.3219691e-05,
#        1.4540905e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 4.72223  ,  4.4427776,  1.2758234, -6.6123867, -2.0220768],
#       dtype=float32), 'probabilities': array([5.5889428e-01, 4.2263463e-01, 1.7806325e-02, 6.6798730e-06,
#        6.5813429e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -2.4871542, -12.432047 ,   0.5320603,   5.466739 ,  -0.4659236],
#       dtype=float32), 'probabilities': array([3.4774622e-04, 1.6682085e-08, 7.1201753e-03, 9.8990738e-01,
#        2.6246523e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.6140945 , -7.432529  ,  0.14151675,  2.3999462 ,  2.9365208 ],
#       dtype=float32), 'probabilities': array([6.3754870e-03, 1.8949566e-05, 3.6894836e-02, 3.5301167e-01,
#        6.0369903e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.88180315,  4.5021577 ,  3.8232994 , -5.175048  , -6.03681   ],
#       dtype=float32), 'probabilities': array([1.7452519e-02, 6.5186578e-01, 3.3062354e-01, 4.0869658e-05,
#        1.7264059e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -3.1993492 , -11.963045  ,   1.1581612 ,   5.259517  ,
#          0.28931475], dtype=float32), 'probabilities': array([2.0710315e-04, 3.2371410e-08, 1.6166994e-02, 9.7684485e-01,
#        6.7810058e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.9588745 , -4.1008177 ,  1.1302927 ,  0.40348414,  0.20441961],
#       dtype=float32), 'probabilities': array([0.00325895, 0.0028277 , 0.52878004, 0.25563842, 0.20949493],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-5.3388968, -7.2963524,  2.6398509,  0.9505504,  2.5726216],
#       dtype=float32), 'probabilities': array([1.6163448e-04, 2.2825579e-05, 4.7169358e-01, 8.7097570e-02,
#        4.4102445e-01], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.8132262,  3.046831 ,  2.7892916, -4.4834185, -3.8598464],
#       dtype=float32), 'probabilities': array([3.0850515e-01, 3.8968673e-01, 3.0120885e-01, 2.0910759e-04,
#        3.9010707e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -2.4542742 , -10.204823  ,  -0.14722747,   3.7250762 ,
#          1.0281324 ], dtype=float32), 'probabilities': array([1.9001963e-03, 8.1804632e-07, 1.9086933e-02, 9.1718358e-01,
#        6.1828464e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.8449569, -4.7461247,  2.2939065,  3.0155833, -0.4458611],
#       dtype=float32), 'probabilities': array([5.0778971e-03, 2.7907614e-04, 3.1854403e-01, 6.5552574e-01,
#        2.0573281e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -1.3630395, -11.45337  ,  -1.0343318,   3.79378  ,   2.055375 ],
#       dtype=float32), 'probabilities': array([4.8421095e-03, 2.0084428e-07, 6.7265215e-03, 8.4064525e-01,
# ...
# {'logits': array([-11.082168  ,  -5.0786066 ,   2.2954242 ,   0.53799176,
#          4.005224  ], dtype=float32), 'probabilities': array([2.3123198e-07, 9.3618422e-05, 1.4923209e-01, 2.5740620e-02,
#        8.2493347e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.2539315,  4.8258758,  2.1339638, -5.07359  , -2.5390954],
#       dtype=float32), 'probabilities': array([1.6271849e-01, 7.8365260e-01, 5.3093467e-02, 3.9340539e-05,
#        4.9608632e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 1.6719071,  3.4488833,  2.479543 , -4.59592  , -3.447639 ],
#       dtype=float32), 'probabilities': array([1.0914138e-01, 6.4523870e-01, 2.4476045e-01, 2.0696961e-04,
#        6.5252738e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 3.6265743,  4.046758 ,  2.8565423, -5.938313 , -5.1793404],
#       dtype=float32), 'probabilities': array([3.3495677e-01, 5.0988507e-01, 1.5508442e-01, 2.3496921e-05,
#        5.0191295e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.7707832 , -3.2688172 ,  0.6884088 , -0.22649556,  0.4555918 ],
#       dtype=float32), 'probabilities': array([0.03721654, 0.00832047, 0.43526074, 0.17434584, 0.34485647],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([  2.9020836, -15.36886  ,  -8.1586895,  -4.2643247,  11.778659 ],
#       dtype=float32), 'probabilities': array([1.3960197e-04, 1.6215188e-12, 2.1941149e-09, 1.0778538e-07,
#        9.9986029e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 4.863526  ,  4.05403   , -0.049312  , -6.3327208 ,  0.48171604],
#       dtype=float32), 'probabilities': array([6.8261695e-01, 3.0382076e-01, 5.0183232e-03, 9.3693343e-06,
#        8.5345628e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-3.00068  , -1.4252074,  2.6905868,  1.3135889, -1.7159212],
#       dtype=float32), 'probabilities': array([0.0026283 , 0.01270263, 0.77868223, 0.19648874, 0.00949813],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -1.3956602, -10.703215 ,  -4.7473664,  -1.0112844,   5.59923  ],
#       dtype=float32), 'probabilities': array([9.1445487e-04, 8.2974147e-08, 3.2028383e-05, 1.3430576e-03,
#        9.9771035e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -3.2940228, -11.731625 ,   0.3743267,   4.805674 ,   0.6938069],
#       dtype=float32), 'probabilities': array([2.9519462e-04, 6.3930024e-08, 1.1567846e-02, 9.7221476e-01,
#        1.5922125e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 5.0429144 ,  3.994654  , -0.34964103, -5.965885  ,  1.17261   ],
#       dtype=float32), 'probabilities': array([7.2676218e-01, 2.5476432e-01, 3.3070087e-03, 1.2031822e-05,
#        1.5154460e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 0.28675583, -9.377511  , -0.143866  ,  3.0002184 ,  3.5241106 ],
#       dtype=float32), 'probabilities': array([2.3697892e-02, 1.5051227e-06, 1.5406111e-02, 3.5739756e-01,
#        6.0349691e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 5.399269  ,  5.138085  , -0.17589968, -6.6917586 ,  1.103399  ],
#       dtype=float32), 'probabilities': array([5.5942178e-01, 4.3083256e-01, 2.1206765e-03, 3.1381417e-06,
#        7.6219626e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -6.25983   , -10.332142  ,   0.43023136,   3.3848803 ,
#          0.75288105], dtype=float32), 'probabilities': array([5.7617126e-05, 9.8167834e-07, 4.6345588e-02, 8.8960278e-01,
#        6.3993134e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.72944665, -9.138631  ,  0.1440289 ,  3.028472  ,  3.3082612 ],
#       dtype=float32), 'probabilities': array([9.7133778e-03, 2.1642531e-06, 2.3265688e-02, 4.1630685e-01,
#        5.5071193e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 2.4987714,  2.4304993,  2.6162412, -3.5420518, -3.3645327],
#       dtype=float32), 'probabilities': array([0.32638404, 0.30484474, 0.36706704, 0.00077666, 0.00092753],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 5.264613 ,  3.9858563,  1.3670344, -6.5741076, -1.9992758],
#       dtype=float32), 'probabilities': array([7.6959676e-01, 2.1424279e-01, 1.5615874e-02, 5.5561291e-06,
#        5.3900940e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 0.34112749,  2.3717654 ,  3.5323129 , -1.3972943 , -3.3283195 ],
#       dtype=float32), 'probabilities': array([0.03017732, 0.22991933, 0.733829  , 0.0053051 , 0.00076924],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.661998  ,  3.3662484 ,  0.2976889 , -5.431168  ,  0.16156077],
#       dtype=float32), 'probabilities': array([7.7067637e-01, 2.1092847e-01, 9.8056588e-03, 3.1876130e-05,
#        8.5577033e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -5.5247674, -10.328406 ,  -2.1168585,  -0.8132042,   5.5998154],
#       dtype=float32), 'probabilities': array([1.4714454e-05, 1.2065631e-07, 4.4440606e-04, 1.6366274e-03,
#        9.9790418e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.93837   , -4.4572616 ,  2.2294574 ,  2.8265133 , -0.57400334],
#       dtype=float32), 'probabilities': array([5.3508510e-03, 4.3100471e-04, 3.4553114e-01, 6.2774789e-01,
#        2.0939182e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.772054 , -6.171759 ,  1.0504373,  2.4843094,  1.2561548],
#       dtype=float32), 'probabilities': array([9.1706002e-03, 1.1262374e-04, 1.5423755e-01, 6.4701283e-01,
#        1.8946636e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.2064757,  3.5104387,  3.015725 , -5.598857 , -4.3547754],
#       dtype=float32), 'probabilities': array([3.1424528e-01, 4.2587113e-01, 2.5967297e-01, 4.7115227e-05,
#        1.6347789e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-0.60438514, -8.579199  , -0.13723457,  2.5492883 ,  3.2291448 ],
#       dtype=float32), 'probabilities': array([1.3842141e-02, 4.7619583e-06, 2.2084331e-02, 3.2420987e-01,
#        6.3985884e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.2809236 , -7.5678496 ,  0.3336891 ,  3.1331463 ,  0.73568463],
#       dtype=float32), 'probabilities': array([1.4203817e-03, 1.9526151e-05, 5.2748680e-02, 8.6696255e-01,
#        7.8848965e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.7570336,  4.2349696,  2.9180791, -6.106665 , -4.466629 ],
#       dtype=float32), 'probabilities': array([3.2838300e-01, 5.2959716e-01, 1.4191470e-01, 1.7085620e-05,
#        8.8082408e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-0.91388226,  1.8582358 ,  3.238174  , -2.0797222 , -3.958296  ],
#       dtype=float32), 'probabilities': array([1.2358447e-02, 1.9764210e-01, 7.8555930e-01, 3.8516440e-03,
#        5.8856123e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.5235934 , -5.7680445 , -0.42170262,  0.32653075,  2.6602318 ],
#       dtype=float32), 'probabilities': array([1.3157687e-02, 1.8872877e-04, 3.9602697e-02, 8.3690926e-02,
#        8.6335993e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.2064757,  3.5104387,  3.015725 , -5.598857 , -4.3547754],
#       dtype=float32), 'probabilities': array([3.1424528e-01, 4.2587113e-01, 2.5967297e-01, 4.7115227e-05,
#        1.6347789e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-0.2649255 , -0.57277423,  2.7195315 , -0.9663177 , -2.349077  ],
#       dtype=float32), 'probabilities': array([0.04518529, 0.03321239, 0.8935735 , 0.02240713, 0.00562162],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -3.848441  , -10.235813  ,  -0.34032834,   3.1829143 ,
#          0.58460164], dtype=float32), 'probabilities': array([7.9991255e-04, 1.3459894e-06, 2.6705233e-02, 9.0515119e-01,
#        6.7342348e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.1518853 , -2.0689585 ,  2.7289255 , -0.54589015, -0.36572284],
#       dtype=float32), 'probabilities': array([0.00690736, 0.00750458, 0.90995723, 0.03441808, 0.04121282],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-11.082168  ,  -5.0786066 ,   2.2954242 ,   0.53799176,
#          4.005224  ], dtype=float32), 'probabilities': array([2.3123198e-07, 9.3618422e-05, 1.4923209e-01, 2.5740620e-02,
#        8.2493347e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 2.8371353 ,  2.702286  ,  1.4373436 , -3.9487906 , -0.33882475],
#       dtype=float32), 'probabilities': array([0.4622397 , 0.40392706, 0.11401065, 0.00052213, 0.01930036],
#       dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([  2.3626392, -13.171289 ,  -1.3318298,   3.798446 ,   6.1684217],
#       dtype=float32), 'probabilities': array([1.9924957e-02, 3.5735370e-09, 4.9534731e-04, 8.3745278e-02,
#        8.9583445e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-4.8032494, -6.33917  ,  2.7931726,  0.7204041,  1.6004198],
#       dtype=float32), 'probabilities': array([3.5126161e-04, 7.5611708e-05, 6.9938278e-01, 8.8008180e-02,
#        2.1218222e-01], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.7978029 ,  0.03181063,  3.3477006 ,  0.2747714 , -2.5377295 ],
#       dtype=float32), 'probabilities': array([0.00533869, 0.03326795, 0.9164288 , 0.04241725, 0.00254735],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.8988545 ,  0.15971749,  3.0321598 , -0.35287464, -2.4101791 ],
#       dtype=float32), 'probabilities': array([0.00655107, 0.0513261 , 0.9074529 , 0.0307413 , 0.00392868],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.912618 ,  4.311258 ,  1.240698 , -6.3046837, -2.1508286],
#       dtype=float32), 'probabilities': array([6.3517773e-01, 3.4811908e-01, 1.6151043e-02, 8.5365573e-06,
#        5.4359972e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-2.8847482 , -4.1870255 ,  2.2702773 ,  2.6252615 , -0.33877826],
#       dtype=float32), 'probabilities': array([0.0023016 , 0.00062583, 0.39886692, 0.56884736, 0.02935821],
#       dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.121698  , -4.2902584 ,  3.181915  , -0.2015832 , -0.10138416],
#       dtype=float32), 'probabilities': array([6.2749936e-04, 5.3016155e-04, 9.3224913e-01, 3.1629868e-02,
#        3.4963369e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.7702186,  3.9379652,  3.5117881, -4.516966 , -5.433282 ],
#       dtype=float32), 'probabilities': array([2.4830971e-02, 5.8983231e-01, 3.8516092e-01, 1.2554476e-04,
#        5.0216629e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-3.9178622 , -3.8558538 ,  2.67334   ,  0.39410728, -1.1035683 ],
#       dtype=float32), 'probabilities': array([0.00121656, 0.00129439, 0.8864552 , 0.09073996, 0.02029394],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.7794328 ,  3.2752192 ,  0.87213916, -3.97042   ,  0.52181184],
#       dtype=float32), 'probabilities': array([3.4529901e-01, 5.6690806e-01, 5.1270586e-02, 4.0436324e-04,
#        3.6117937e-02], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 4.021766 ,  4.4478574,  1.3087782, -6.5036836, -2.0488696],
#       dtype=float32), 'probabilities': array([3.8462496e-01, 5.8896095e-01, 2.5515364e-02, 1.0325062e-05,
#        8.8836980e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -2.7930856 , -11.210117  ,   1.0261014 ,   5.446347  ,
#         -0.82263327], dtype=float32), 'probabilities': array([2.6033976e-04, 5.7553358e-08, 1.1862942e-02, 9.8600906e-01,
#        1.8676576e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -2.290565  , -10.702539  ,  -0.29610544,   3.7258718 ,
#          1.1161721 ], dtype=float32), 'probabilities': array([2.2290098e-03, 4.9526506e-07, 1.6379271e-02, 9.1414940e-01,
#        6.7241743e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.4803643 , -6.6851997 ,  1.3915987 ,  1.9666717 , -0.58024096],
#       dtype=float32), 'probabilities': array([7.08658388e-03, 1.05754756e-04, 3.40415239e-01, 6.05006456e-01,
#        4.73859832e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.040733 , -6.5375485,  1.3763392,  2.9465234,  1.236665 ],
#       dtype=float32), 'probabilities': array([4.8892158e-03, 5.4487537e-05, 1.4902353e-01, 7.1643567e-01,
#        1.2959705e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.4182487 , -1.0032604 ,  1.6994195 , -0.35081685, -1.4579296 ],
#       dtype=float32), 'probabilities': array([0.0129787 , 0.05342601, 0.7970979 , 0.10259009, 0.03390723],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -2.98689  , -10.657953 ,  -3.6147935,  -0.3268441,   5.225065 ],
#       dtype=float32), 'probabilities': array([2.7022860e-04, 1.2595946e-07, 1.4422352e-04, 3.8634425e-03,
#        9.9572194e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.1850512, -9.592915 , -0.5279222,  3.35209  ,  2.0337403],
#       dtype=float32), 'probabilities': array([3.0474148e-03, 1.8481501e-06, 1.5981348e-02, 7.7389359e-01,
#        2.0707577e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.5377887,  2.048218 ,  3.1607943, -2.1233706, -4.36716  ],
#       dtype=float32), 'probabilities': array([6.7797978e-03, 2.4468073e-01, 7.4436420e-01, 3.7748686e-03,
#        4.0034699e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.3189764,  4.652144 ,  2.3828192, -6.1891203, -3.9636853],
#       dtype=float32), 'probabilities': array([1.9282936e-01, 7.3140925e-01, 7.5614527e-02, 1.4317229e-05,
#        1.3254193e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.4341755 , -1.0918214 ,  2.6307094 , -0.34568483, -1.0341011 ],
#       dtype=float32), 'probabilities': array([0.01535433, 0.02162288, 0.894516  , 0.04559913, 0.02290768],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}

# %%
df_test.head()
# Out:
#       A_State  Hour  Minute  IsoWeekday
# 1476        2    10      15           2
# 2500        4     2      45           6
# 1624        4    23      30           3
# 1638        3     3       0           4
# 2095        2    20      45           4
